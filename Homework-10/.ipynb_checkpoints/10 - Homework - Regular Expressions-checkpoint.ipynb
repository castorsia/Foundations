# %% [markdown]
# # Homework 10: Cleaning data with Regular Expressions
#
# Time to use regular expressions!
#
# # Hints and notes
#
# ### Opening files in subdirectories
#
# Notice that this notebook might be **homework/**, but!!! the csvs and text files might be in **homework/scraped/** or **/homework/scraped/minutes_pdfs** or **/homework/pdfs/**. To open a file in a subdirectory, instead of having the filename be `"file.csv"` you'll just use `"some/subfolder/file.csv"`
#
# ### Opening text files
#
# This will open up a file, read it in and show you the first 500 characters.
#
# ```python
# contents = open("your-filename.txt").read()
# contents[0:500]
# ```
#
# > You might need `open("your-filename.txt", encoding="utf8").read()`
#
# ### Using regex
#
# For some dumb reason you need to put `r` in front of the string you use when you're talking about regex. Just plain `"(\d\d\d)"` will usually work, but *sometimes* it won't and you'll need `r"(\d\d\d)`. It's best to just use the `r` all of the time, if you can remember!
#
# ### Using `.str.extract`
#
# When you use `.str.extract`, you're always going to **capture one thing** and save it to a new column. You need to wrap the things you're interested in with parenthesis `(` `)`.
#
# ```python
# df['phone_number'] = df['old_column'].str.extract(r"My phone number is (\d\d\d-\d\d\d-\d\d\d\d)")
# ```
#
# ### Setting pandas options
#
# Pandas has a lot of options, like how many columns or rows it will show you, or how many characters it will show in a column before it stops showing you anything. Here are a few useful ones:
#
# * `display.max_cols`: Number of columns to show at once
# * `display.max_rows`: Number of rows to show at once
# * `display.max_colwidth`: Maximum number of characters displayed from a string
#
# You can set them using `pd.set_option("display.max_rows", 1000)`, for example, to show 1000 rows at a time. You can find a lot more at https://pandas.pydata.org/pandas-docs/stable/generated/pandas.set_option.html
#
# ### Regular expressions reference
#
# I personally think http://www.regular-expressions.info/ is a wonderful wonderful reference (and tutorial), even if it's ugly! But here's a quick reference for you:
#
# * `\d` is a digit
# * `\d*` is zero or more digits
# * `\d+` is one or more digits
# * `.` matches anything for ONE character
# * `.*` is "give me anything forever"
# * `\s` is whitespace, a.k.a. spaces and tabs
# * `\w` is a word character, which includes capital and lowercase letters, numbers and hyphens.
# * You can put `*` after anything, so `\w*` would mean "as many word characters as you can find"
# * `\b` is a word boundary (you'll need the `r""` thing for this one)
# * `( )` is a "capture group" for saving something
# * `\1` is used when doing find/replace to say "put the first captured group here" (note, it's a dollar sign instead of a backslash in some editors)
# * `[ABCDE]` is a character class, which means "match one of these, I don't care which"
# * dollar sign means "end of the line"
# * caret ^ means "beginning of the line"
# * `\.` means "no really seriously I mean a period not just anything"
# * You can use `\` with anything else that would normally be a special character, too, not just periods. `(` or `[` or whatever.
#
# ### Cleaning up extracted columns
#
# Sometimes you get `\n` (newlines) or spaces or `\t` (tabs) or stuff at the beginning or the end of your column. `.str.strip()` will usually take care of that, just attach it after your `.str.extract()`
#
# After you extract something, it's still a string even though you look at it and know it's a number. Use `.astype(int)` to turn it into an integer (no decimal) or `.astype(float)` to turn it into a float (yes decimal)
#
# ### Writing regular expressions in general
#
# Even if I'm using regex in pandas or Python, I like to test them in my text editor with "Find." The highlighting really helps me see if I'm matching things! I also like to think "what stays the same?" when designing patterns, write those parts first, then fill in the blanks with what I want to capture.

# %% [markdown]
# ## Importing
#
# There might be more, I just wanted to put this up here for the `pd.set_option` part. It allows you to see a lot of content in a single column of pandas, which will be important for some parts below.

# %%
import re
import pandas as pd
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# # Part 1: Using `.str.extract` to pull data from columns in pandas
#
# ## 1.1 H&M
#
# Open up `hm.csv` from the `scraped` directory. I want **four new columns**:
#
# 1. `price_original`, the original price, one of the new price
# 2. `price_discounted`, the discounted price
# 3. `pct_discount`, the percent discount
# 4. `article_id`, the article id (from the url)
#
# Save as **hm_cleaned.csv**.
#
# **Note:** When you look at it, it... won't look right. I don't know why, pandas is weird. Look at the `price` column by itself using `df['price']` before you write your regex.
#
# **Tip:** Remember that `$` is a special regex symbol! You might need to escape it.
#
# **Tip:** When doing `.str.extract`, the whole match doesn't get captured, only what you put `()` around! Think about anchoring to different points of the string, or things in the string.
#
# **Tip:** Not all prices have cents!
#
# **Tip:** Your first instinct about how to compute the percent discount is probably wrong

# %%
df = pd.read_csv('C:/Users/ilias/Documents/LEDE_COLUMBIA_J_SCHOOL/Foundations/Assignments/Class-10/Homework-10/scraped/hm.csv')

# %%
display.max_cols: 10
display.max_rows: 20
display.max_colwidth: 500


df
# Out:
#                               name          price  \
# 0     Washed Linen Duvet Cover Set    $59.99 $129
# 1              Candle in Glass Jar   $6.99 $17.99
# 2           Glittery Cushion Cover   $7.99 $17.99
# 3     Textured-weave Cushion Cover   $6.99 $12.99
# 4                   Stoneware Bowl  $17.99 $24.99
# 5         Slub-weave Cushion Cover    $3.99 $9.99
# 6            Braided Cushion Cover   $7.99 $17.99
# 7     Jacquard-weave Cushion Cover   $7.99 $17.99
# 8   Scented Candle in Glass Holder   $9.99 $17.99
# 9            2-pack Curtain Panels  $27.99 $34.99
# 10                   Porcelain Cup    $2.99 $5.99
# 11     Cotton Canvas Cushion Cover    $2.99 $5.99
# 12       Color-block Cushion Cover   $9.99 $12.99
# 13      King/Queen Duvet Cover Set  $39.99 $49.99
# 14      Star-print Duvet Cover Set  $39.99 $49.99
# 15           Faux Fur Seat Cushion   $7.99 $17.99
# 16       Patterned Duvet Cover Set  $19.99 $29.99
# 17                   Patterned Mug    $2.99 $5.99
# 18               Metal Storage Box   $7.99 $17.99
# 19                      Metal Tray  $14.99 $24.99
# 20          Porcelain Serving Dish   $9.99 $24.99
# 21                       Metal Box   $7.99 $12.99
# 22                   Stoneware Jar   $7.99 $17.99
# 23               Glittery Placemat    $4.99 $9.99
# 24                 Porcelain Plate   $9.99 $12.99
# 25               Metal Storage Box   $7.99 $17.99
# 26                  Bottle Stopper    $3.99 $6.99
# 27                      Round Tray   $7.99 $17.99
# 28                  Bottle Stopper    $2.99 $6.99
# 29                 Porcelain Plate   $9.99 $12.99
# 30           2-pack Curtain Panels  $14.99 $34.99
# 31             Candle in Glass Jar   $7.99 $17.99
# 32           Satin Duvet Cover Set  $24.99 $49.99
# 33                      Pile Throw  $29.99 $79.99
# 34    Jacquard-weave Cushion Cover   $4.99 $12.99
# 35       Patterned Duvet Cover Set  $19.99 $24.99
# 36        Slub-weave Cushion Cover    $2.99 $5.99
# 37             Tall Stoneware Vase  $14.99 $34.99
# 38    Jacquard-weave Cushion Cover   $6.99 $17.99
# 39          Glittery Cushion Cover   $6.99 $17.99
# 40          Glittery Cushion Cover   $6.99 $17.99
# 41                  Wool-blend Rug       $99 $199
# 42    Washed Linen Duvet Cover Set     $54.99 $99
# 43     Cotton Velvet Cushion Cover   $6.99 $17.99
# 44       Color-block Cushion Cover   $4.99 $12.99
# 45        Scented Candle in Holder   $7.99 $17.99
# 46        Slub-weave Cushion Cover    $3.99 $9.99
# 47    Jacquard-weave Cushion Cover   $6.99 $17.99
# 48         Texture-patterned Plate   $4.99 $12.99
# 49     Cotton Canvas Cushion Cover    $2.99 $5.99
# 50               Glittery Placemat    $4.99 $9.99
# 51    Textured-weave Cushion Cover   $6.99 $12.99
# 52        Slub-weave Cushion Cover    $2.99 $5.99
# 53                  Faux Fur Throw  $34.99 $79.99
# 54           Faux Fur Seat Cushion   $7.99 $17.99
# 55                  Faux Fur Throw  $34.99 $79.99
# 56         Patterned Cushion Cover    $2.99 $5.99
# 57           Sequined Table Runner  $14.99 $24.99
# 58    Jacquard-weave Cushion Cover   $5.99 $12.99
# 59      Cushion Cover with Tassels  $12.99 $17.99
#
#                                                    url
# 0   http://www.hm.com/us/product/13472?article=13472-N
# 1   http://www.hm.com/us/product/35079?article=35079-D
# 2   http://www.hm.com/us/product/72462?article=72462-A
# 3   http://www.hm.com/us/product/58926?article=58926-C
# 4   http://www.hm.com/us/product/74242?article=74242-A
# 5   http://www.hm.com/us/product/70965?article=70965-D
# 6   http://www.hm.com/us/product/62818?article=62818-B
# 7   http://www.hm.com/us/product/69163?article=69163-B
# 8   http://www.hm.com/us/product/40910?article=40910-C
# 9   http://www.hm.com/us/product/69699?article=69699-B
# 10  http://www.hm.com/us/product/76916?article=76916-A
# 11  http://www.hm.com/us/product/68473?article=68473-C
# 12  http://www.hm.com/us/product/74498?article=74498-A
# 13  http://www.hm.com/us/product/41512?article=41512-E
# 14  http://www.hm.com/us/product/76727?article=76727-A
# 15  http://www.hm.com/us/product/76977?article=76977-A
# 16  http://www.hm.com/us/product/73369?article=73369-A
# 17  http://www.hm.com/us/product/59417?article=59417-D
# 18  http://www.hm.com/us/product/76797?article=76797-A
# 19  http://www.hm.com/us/product/76794?article=76794-A
# 20  http://www.hm.com/us/product/80432?article=80432-A
# 21  http://www.hm.com/us/product/78352?article=78352-A
# 22  http://www.hm.com/us/product/70658?article=70658-A
# 23  http://www.hm.com/us/product/72111?article=72111-A
# 24  http://www.hm.com/us/product/77665?article=77665-A
# 25  http://www.hm.com/us/product/70603?article=70603-A
# 26  http://www.hm.com/us/product/72262?article=72262-B
# 27  http://www.hm.com/us/product/70427?article=70427-A
# 28  http://www.hm.com/us/product/72262?article=72262-A
# 29  http://www.hm.com/us/product/77665?article=77665-B
# 30  http://www.hm.com/us/product/73380?article=73380-A
# 31  http://www.hm.com/us/product/35079?article=35079-C
# 32  http://www.hm.com/us/product/74773?article=74773-A
# 33  http://www.hm.com/us/product/75033?article=75033-A
# 34  http://www.hm.com/us/product/60637?article=60637-C
# 35  http://www.hm.com/us/product/70306?article=70306-A
# 36  http://www.hm.com/us/product/60621?article=60621-B
# 37  http://www.hm.com/us/product/69643?article=69643-A
# 38  http://www.hm.com/us/product/72455?article=72455-B
# 39  http://www.hm.com/us/product/72460?article=72460-B
# 40  http://www.hm.com/us/product/72462?article=72462-B
# 41  http://www.hm.com/us/product/71871?article=71871-A
# 42  http://www.hm.com/us/product/73734?article=73734-A
# 43  http://www.hm.com/us/product/74267?article=74267-A
# 44  http://www.hm.com/us/product/73344?article=73344-A
# 45  http://www.hm.com/us/product/73325?article=73325-C
# 46  http://www.hm.com/us/product/74264?article=74264-A
# 47  http://www.hm.com/us/product/72455?article=72455-A
# 48  http://www.hm.com/us/product/70799?article=70799-B
# 49  http://www.hm.com/us/product/68473?article=68473-D
# 50  http://www.hm.com/us/product/72111?article=72111-C
# 51  http://www.hm.com/us/product/58926?article=58926-B
# 52  http://www.hm.com/us/product/58211?article=58211-A
# 53  http://www.hm.com/us/product/75469?article=75469-A
# 54  http://www.hm.com/us/product/76982?article=76982-A
# 55  http://www.hm.com/us/product/74825?article=74825-A
# 56  http://www.hm.com/us/product/74263?article=74263-A
# 57  http://www.hm.com/us/product/78047?article=78047-A
# 58  http://www.hm.com/us/product/60637?article=60637-G
# 59  http://www.hm.com/us/product/78381?article=78381-A

# %%
df['price']
# Out:
# 0       $59.99 $129
# 1      $6.99 $17.99
# 2      $7.99 $17.99
# 3      $6.99 $12.99
# 4     $17.99 $24.99
# 5       $3.99 $9.99
# 6      $7.99 $17.99
# 7      $7.99 $17.99
# 8      $9.99 $17.99
# 9     $27.99 $34.99
# 10      $2.99 $5.99
# 11      $2.99 $5.99
# 12     $9.99 $12.99
# 13    $39.99 $49.99
# 14    $39.99 $49.99
# 15     $7.99 $17.99
# 16    $19.99 $29.99
# 17      $2.99 $5.99
# 18     $7.99 $17.99
# 19    $14.99 $24.99
# 20     $9.99 $24.99
# 21     $7.99 $12.99
# 22     $7.99 $17.99
# 23      $4.99 $9.99
# 24     $9.99 $12.99
# 25     $7.99 $17.99
# 26      $3.99 $6.99
# 27     $7.99 $17.99
# 28      $2.99 $6.99
# 29     $9.99 $12.99
# 30    $14.99 $34.99
# 31     $7.99 $17.99
# 32    $24.99 $49.99
# 33    $29.99 $79.99
# 34     $4.99 $12.99
# 35    $19.99 $24.99
# 36      $2.99 $5.99
# 37    $14.99 $34.99
# 38     $6.99 $17.99
# 39     $6.99 $17.99
# 40     $6.99 $17.99
# 41         $99 $199
# 42       $54.99 $99
# 43     $6.99 $17.99
# 44     $4.99 $12.99
# 45     $7.99 $17.99
# 46      $3.99 $9.99
# 47     $6.99 $17.99
# 48     $4.99 $12.99
# 49      $2.99 $5.99
# 50      $4.99 $9.99
# 51     $6.99 $12.99
# 52      $2.99 $5.99
# 53    $34.99 $79.99
# 54     $7.99 $17.99
# 55    $34.99 $79.99
# 56      $2.99 $5.99
# 57    $14.99 $24.99
# 58     $5.99 $12.99
# 59    $12.99 $17.99
# Name: price, dtype: object

# %%
#df['price_new'] = df['price'].str.extract(r"^\$(\d+)\s")

# %%
#df['price'].str.extract(r"^\$(\d)\s")

#df['price'].str.extract(r"^\$(\d+.\d+)\s")

# %%
df['price_discounted'] = df['price'].str.extract(r"^\$(.*)\s")

# %%
df['price_discounted'] = df['price_discounted'].astype('float')

# %%
df['price_original'] = df['price'].str.extract(r"^\$.*\s+\$(.*)")

# %%
df['price_original'] = df['price_original'].astype('float')

# %%
df['discount'] = df['price_original'] - df['price_discounted']
df['discount_percentage'] = round((df['discount'] / df['price_original']) * 100, 1)
df['discount_percentage']
# Out:
# 0     53.5
# 1     61.1
# 2     55.6
# 3     46.2
# 4     28.0
# 5     60.1
# 6     55.6
# 7     55.6
# 8     44.5
# 9     20.0
# 10    50.1
# 11    50.1
# 12    23.1
# 13    20.0
# 14    20.0
# 15    55.6
# 16    33.3
# 17    50.1
# 18    55.6
# 19    40.0
# 20    60.0
# 21    38.5
# 22    55.6
# 23    50.1
# 24    23.1
# 25    55.6
# 26    42.9
# 27    55.6
# 28    57.2
# 29    23.1
# 30    57.2
# 31    55.6
# 32    50.0
# 33    62.5
# 34    61.6
# 35    20.0
# 36    50.1
# 37    57.2
# 38    61.1
# 39    61.1
# 40    61.1
# 41    50.3
# 42    44.5
# 43    61.1
# 44    61.6
# 45    55.6
# 46    60.1
# 47    61.1
# 48    61.6
# 49    50.1
# 50    50.1
# 51    46.2
# 52    50.1
# 53    56.3
# 54    55.6
# 55    56.3
# 56    50.1
# 57    40.0
# 58    53.9
# 59    27.8
# Name: discount_percentage, dtype: float64

# %%
df['url']
# Out:
# 0     http://www.hm.com/us/product/13472?article=13472-N
# 1     http://www.hm.com/us/product/35079?article=35079-D
# 2     http://www.hm.com/us/product/72462?article=72462-A
# 3     http://www.hm.com/us/product/58926?article=58926-C
# 4     http://www.hm.com/us/product/74242?article=74242-A
# 5     http://www.hm.com/us/product/70965?article=70965-D
# 6     http://www.hm.com/us/product/62818?article=62818-B
# 7     http://www.hm.com/us/product/69163?article=69163-B
# 8     http://www.hm.com/us/product/40910?article=40910-C
# 9     http://www.hm.com/us/product/69699?article=69699-B
# 10    http://www.hm.com/us/product/76916?article=76916-A
# 11    http://www.hm.com/us/product/68473?article=68473-C
# 12    http://www.hm.com/us/product/74498?article=74498-A
# 13    http://www.hm.com/us/product/41512?article=41512-E
# 14    http://www.hm.com/us/product/76727?article=76727-A
# 15    http://www.hm.com/us/product/76977?article=76977-A
# 16    http://www.hm.com/us/product/73369?article=73369-A
# 17    http://www.hm.com/us/product/59417?article=59417-D
# 18    http://www.hm.com/us/product/76797?article=76797-A
# 19    http://www.hm.com/us/product/76794?article=76794-A
# 20    http://www.hm.com/us/product/80432?article=80432-A
# 21    http://www.hm.com/us/product/78352?article=78352-A
# 22    http://www.hm.com/us/product/70658?article=70658-A
# 23    http://www.hm.com/us/product/72111?article=72111-A
# 24    http://www.hm.com/us/product/77665?article=77665-A
# 25    http://www.hm.com/us/product/70603?article=70603-A
# 26    http://www.hm.com/us/product/72262?article=72262-B
# 27    http://www.hm.com/us/product/70427?article=70427-A
# 28    http://www.hm.com/us/product/72262?article=72262-A
# 29    http://www.hm.com/us/product/77665?article=77665-B
# 30    http://www.hm.com/us/product/73380?article=73380-A
# 31    http://www.hm.com/us/product/35079?article=35079-C
# 32    http://www.hm.com/us/product/74773?article=74773-A
# 33    http://www.hm.com/us/product/75033?article=75033-A
# 34    http://www.hm.com/us/product/60637?article=60637-C
# 35    http://www.hm.com/us/product/70306?article=70306-A
# 36    http://www.hm.com/us/product/60621?article=60621-B
# 37    http://www.hm.com/us/product/69643?article=69643-A
# 38    http://www.hm.com/us/product/72455?article=72455-B
# 39    http://www.hm.com/us/product/72460?article=72460-B
# 40    http://www.hm.com/us/product/72462?article=72462-B
# 41    http://www.hm.com/us/product/71871?article=71871-A
# 42    http://www.hm.com/us/product/73734?article=73734-A
# 43    http://www.hm.com/us/product/74267?article=74267-A
# 44    http://www.hm.com/us/product/73344?article=73344-A
# 45    http://www.hm.com/us/product/73325?article=73325-C
# 46    http://www.hm.com/us/product/74264?article=74264-A
# 47    http://www.hm.com/us/product/72455?article=72455-A
# 48    http://www.hm.com/us/product/70799?article=70799-B
# 49    http://www.hm.com/us/product/68473?article=68473-D
# 50    http://www.hm.com/us/product/72111?article=72111-C
# 51    http://www.hm.com/us/product/58926?article=58926-B
# 52    http://www.hm.com/us/product/58211?article=58211-A
# 53    http://www.hm.com/us/product/75469?article=75469-A
# 54    http://www.hm.com/us/product/76982?article=76982-A
# 55    http://www.hm.com/us/product/74825?article=74825-A
# 56    http://www.hm.com/us/product/74263?article=74263-A
# 57    http://www.hm.com/us/product/78047?article=78047-A
# 58    http://www.hm.com/us/product/60637?article=60637-G
# 59    http://www.hm.com/us/product/78381?article=78381-A
# Name: url, dtype: object

# %%
df['id'] = df['url'].str.extract(r"^h.*\d+\?a\w+=(\d+-\w)")   
#$.*\s+\$(.*)")
df['id']
# Out:
# 0     13472-N
# 1     35079-D
# 2     72462-A
# 3     58926-C
# 4     74242-A
# 5     70965-D
# 6     62818-B
# 7     69163-B
# 8     40910-C
# 9     69699-B
# 10    76916-A
# 11    68473-C
# 12    74498-A
# 13    41512-E
# 14    76727-A
# 15    76977-A
# 16    73369-A
# 17    59417-D
# 18    76797-A
# 19    76794-A
# 20    80432-A
# 21    78352-A
# 22    70658-A
# 23    72111-A
# 24    77665-A
# 25    70603-A
# 26    72262-B
# 27    70427-A
# 28    72262-A
# 29    77665-B
# 30    73380-A
# 31    35079-C
# 32    74773-A
# 33    75033-A
# 34    60637-C
# 35    70306-A
# 36    60621-B
# 37    69643-A
# 38    72455-B
# 39    72460-B
# 40    72462-B
# 41    71871-A
# 42    73734-A
# 43    74267-A
# 44    73344-A
# 45    73325-C
# 46    74264-A
# 47    72455-A
# 48    70799-B
# 49    68473-D
# 50    72111-C
# 51    58926-B
# 52    58211-A
# 53    75469-A
# 54    76982-A
# 55    74825-A
# 56    74263-A
# 57    78047-A
# 58    60637-G
# 59    78381-A
# Name: id, dtype: object

# %%
df = df.drop('discount', 1)

# %%
df
# Out:
#                               name          price  \
# 0     Washed Linen Duvet Cover Set    $59.99 $129
# 1              Candle in Glass Jar   $6.99 $17.99
# 2           Glittery Cushion Cover   $7.99 $17.99
# 3     Textured-weave Cushion Cover   $6.99 $12.99
# 4                   Stoneware Bowl  $17.99 $24.99
# 5         Slub-weave Cushion Cover    $3.99 $9.99
# 6            Braided Cushion Cover   $7.99 $17.99
# 7     Jacquard-weave Cushion Cover   $7.99 $17.99
# 8   Scented Candle in Glass Holder   $9.99 $17.99
# 9            2-pack Curtain Panels  $27.99 $34.99
# 10                   Porcelain Cup    $2.99 $5.99
# 11     Cotton Canvas Cushion Cover    $2.99 $5.99
# 12       Color-block Cushion Cover   $9.99 $12.99
# 13      King/Queen Duvet Cover Set  $39.99 $49.99
# 14      Star-print Duvet Cover Set  $39.99 $49.99
# 15           Faux Fur Seat Cushion   $7.99 $17.99
# 16       Patterned Duvet Cover Set  $19.99 $29.99
# 17                   Patterned Mug    $2.99 $5.99
# 18               Metal Storage Box   $7.99 $17.99
# 19                      Metal Tray  $14.99 $24.99
# 20          Porcelain Serving Dish   $9.99 $24.99
# 21                       Metal Box   $7.99 $12.99
# 22                   Stoneware Jar   $7.99 $17.99
# 23               Glittery Placemat    $4.99 $9.99
# 24                 Porcelain Plate   $9.99 $12.99
# 25               Metal Storage Box   $7.99 $17.99
# 26                  Bottle Stopper    $3.99 $6.99
# 27                      Round Tray   $7.99 $17.99
# 28                  Bottle Stopper    $2.99 $6.99
# 29                 Porcelain Plate   $9.99 $12.99
# 30           2-pack Curtain Panels  $14.99 $34.99
# 31             Candle in Glass Jar   $7.99 $17.99
# 32           Satin Duvet Cover Set  $24.99 $49.99
# 33                      Pile Throw  $29.99 $79.99
# 34    Jacquard-weave Cushion Cover   $4.99 $12.99
# 35       Patterned Duvet Cover Set  $19.99 $24.99
# 36        Slub-weave Cushion Cover    $2.99 $5.99
# 37             Tall Stoneware Vase  $14.99 $34.99
# 38    Jacquard-weave Cushion Cover   $6.99 $17.99
# 39          Glittery Cushion Cover   $6.99 $17.99
# 40          Glittery Cushion Cover   $6.99 $17.99
# 41                  Wool-blend Rug       $99 $199
# 42    Washed Linen Duvet Cover Set     $54.99 $99
# 43     Cotton Velvet Cushion Cover   $6.99 $17.99
# 44       Color-block Cushion Cover   $4.99 $12.99
# 45        Scented Candle in Holder   $7.99 $17.99
# 46        Slub-weave Cushion Cover    $3.99 $9.99
# 47    Jacquard-weave Cushion Cover   $6.99 $17.99
# 48         Texture-patterned Plate   $4.99 $12.99
# 49     Cotton Canvas Cushion Cover    $2.99 $5.99
# 50               Glittery Placemat    $4.99 $9.99
# 51    Textured-weave Cushion Cover   $6.99 $12.99
# 52        Slub-weave Cushion Cover    $2.99 $5.99
# 53                  Faux Fur Throw  $34.99 $79.99
# 54           Faux Fur Seat Cushion   $7.99 $17.99
# 55                  Faux Fur Throw  $34.99 $79.99
# 56         Patterned Cushion Cover    $2.99 $5.99
# 57           Sequined Table Runner  $14.99 $24.99
# 58    Jacquard-weave Cushion Cover   $5.99 $12.99
# 59      Cushion Cover with Tassels  $12.99 $17.99
#
#                                                    url  price_discounted  \
# 0   http://www.hm.com/us/product/13472?article=13472-N             59.99
# 1   http://www.hm.com/us/product/35079?article=35079-D              6.99
# 2   http://www.hm.com/us/product/72462?article=72462-A              7.99
# 3   http://www.hm.com/us/product/58926?article=58926-C              6.99
# 4   http://www.hm.com/us/product/74242?article=74242-A             17.99
# 5   http://www.hm.com/us/product/70965?article=70965-D              3.99
# 6   http://www.hm.com/us/product/62818?article=62818-B              7.99
# 7   http://www.hm.com/us/product/69163?article=69163-B              7.99
# 8   http://www.hm.com/us/product/40910?article=40910-C              9.99
# 9   http://www.hm.com/us/product/69699?article=69699-B             27.99
# 10  http://www.hm.com/us/product/76916?article=76916-A              2.99
# 11  http://www.hm.com/us/product/68473?article=68473-C              2.99
# 12  http://www.hm.com/us/product/74498?article=74498-A              9.99
# 13  http://www.hm.com/us/product/41512?article=41512-E             39.99
# 14  http://www.hm.com/us/product/76727?article=76727-A             39.99
# 15  http://www.hm.com/us/product/76977?article=76977-A              7.99
# 16  http://www.hm.com/us/product/73369?article=73369-A             19.99
# 17  http://www.hm.com/us/product/59417?article=59417-D              2.99
# 18  http://www.hm.com/us/product/76797?article=76797-A              7.99
# 19  http://www.hm.com/us/product/76794?article=76794-A             14.99
# 20  http://www.hm.com/us/product/80432?article=80432-A              9.99
# 21  http://www.hm.com/us/product/78352?article=78352-A              7.99
# 22  http://www.hm.com/us/product/70658?article=70658-A              7.99
# 23  http://www.hm.com/us/product/72111?article=72111-A              4.99
# 24  http://www.hm.com/us/product/77665?article=77665-A              9.99
# 25  http://www.hm.com/us/product/70603?article=70603-A              7.99
# 26  http://www.hm.com/us/product/72262?article=72262-B              3.99
# 27  http://www.hm.com/us/product/70427?article=70427-A              7.99
# 28  http://www.hm.com/us/product/72262?article=72262-A              2.99
# 29  http://www.hm.com/us/product/77665?article=77665-B              9.99
# 30  http://www.hm.com/us/product/73380?article=73380-A             14.99
# 31  http://www.hm.com/us/product/35079?article=35079-C              7.99
# 32  http://www.hm.com/us/product/74773?article=74773-A             24.99
# 33  http://www.hm.com/us/product/75033?article=75033-A             29.99
# 34  http://www.hm.com/us/product/60637?article=60637-C              4.99
# 35  http://www.hm.com/us/product/70306?article=70306-A             19.99
# 36  http://www.hm.com/us/product/60621?article=60621-B              2.99
# 37  http://www.hm.com/us/product/69643?article=69643-A             14.99
# 38  http://www.hm.com/us/product/72455?article=72455-B              6.99
# 39  http://www.hm.com/us/product/72460?article=72460-B              6.99
# 40  http://www.hm.com/us/product/72462?article=72462-B              6.99
# 41  http://www.hm.com/us/product/71871?article=71871-A             99.00
# 42  http://www.hm.com/us/product/73734?article=73734-A             54.99
# 43  http://www.hm.com/us/product/74267?article=74267-A              6.99
# 44  http://www.hm.com/us/product/73344?article=73344-A              4.99
# 45  http://www.hm.com/us/product/73325?article=73325-C              7.99
# 46  http://www.hm.com/us/product/74264?article=74264-A              3.99
# 47  http://www.hm.com/us/product/72455?article=72455-A              6.99
# 48  http://www.hm.com/us/product/70799?article=70799-B              4.99
# 49  http://www.hm.com/us/product/68473?article=68473-D              2.99
# 50  http://www.hm.com/us/product/72111?article=72111-C              4.99
# 51  http://www.hm.com/us/product/58926?article=58926-B              6.99
# 52  http://www.hm.com/us/product/58211?article=58211-A              2.99
# 53  http://www.hm.com/us/product/75469?article=75469-A             34.99
# 54  http://www.hm.com/us/product/76982?article=76982-A              7.99
# 55  http://www.hm.com/us/product/74825?article=74825-A             34.99
# 56  http://www.hm.com/us/product/74263?article=74263-A              2.99
# 57  http://www.hm.com/us/product/78047?article=78047-A             14.99
# 58  http://www.hm.com/us/product/60637?article=60637-G              5.99
# 59  http://www.hm.com/us/product/78381?article=78381-A             12.99
#
#     price_original  discount_percentage       id
# 0           129.00                 53.5  13472-N
# 1            17.99                 61.1  35079-D
# 2            17.99                 55.6  72462-A
# 3            12.99                 46.2  58926-C
# 4            24.99                 28.0  74242-A
# 5             9.99                 60.1  70965-D
# 6            17.99                 55.6  62818-B
# 7            17.99                 55.6  69163-B
# 8            17.99                 44.5  40910-C
# 9            34.99                 20.0  69699-B
# 10            5.99                 50.1  76916-A
# 11            5.99                 50.1  68473-C
# 12           12.99                 23.1  74498-A
# 13           49.99                 20.0  41512-E
# 14           49.99                 20.0  76727-A
# 15           17.99                 55.6  76977-A
# 16           29.99                 33.3  73369-A
# 17            5.99                 50.1  59417-D
# 18           17.99                 55.6  76797-A
# 19           24.99                 40.0  76794-A
# 20           24.99                 60.0  80432-A
# 21           12.99                 38.5  78352-A
# 22           17.99                 55.6  70658-A
# 23            9.99                 50.1  72111-A
# 24           12.99                 23.1  77665-A
# 25           17.99                 55.6  70603-A
# 26            6.99                 42.9  72262-B
# 27           17.99                 55.6  70427-A
# 28            6.99                 57.2  72262-A
# 29           12.99                 23.1  77665-B
# 30           34.99                 57.2  73380-A
# 31           17.99                 55.6  35079-C
# 32           49.99                 50.0  74773-A
# 33           79.99                 62.5  75033-A
# 34           12.99                 61.6  60637-C
# 35           24.99                 20.0  70306-A
# 36            5.99                 50.1  60621-B
# 37           34.99                 57.2  69643-A
# 38           17.99                 61.1  72455-B
# 39           17.99                 61.1  72460-B
# 40           17.99                 61.1  72462-B
# 41          199.00                 50.3  71871-A
# 42           99.00                 44.5  73734-A
# 43           17.99                 61.1  74267-A
# 44           12.99                 61.6  73344-A
# 45           17.99                 55.6  73325-C
# 46            9.99                 60.1  74264-A
# 47           17.99                 61.1  72455-A
# 48           12.99                 61.6  70799-B
# 49            5.99                 50.1  68473-D
# 50            9.99                 50.1  72111-C
# 51           12.99                 46.2  58926-B
# 52            5.99                 50.1  58211-A
# 53           79.99                 56.3  75469-A
# 54           17.99                 55.6  76982-A
# 55           79.99                 56.3  74825-A
# 56            5.99                 50.1  74263-A
# 57           24.99                 40.0  78047-A
# 58           12.99                 53.9  60637-G
# 59           17.99                 27.8  78381-A

# %% [markdown]
# ## 1.2 Sci-Fi Authors
#
# Open up `sci-fi.csv` to clean. Get rid of the `\n` on the title and and give me six new columns:
#
# * `avg_rating`
# * `rating_count`
# * `total_score`
# * `score_votes`
# * `series` the series the book belongs to
# * `series_no` the book in the series that it is
#
# For series, I'm talking about e.g. `(The Hunger Games, #1)` is `series` "The Hunter Games" and `series_no` 1.
#
# Save as **sci-fi_cleaned.csv**.
#
# **Tip:** You don't need regex to clean the title - there's a special thing that removes whitespace from the beginning/end of strings
#
# **Tip:** Remember that `(` and `)` are special characters
#
# **BONUS:** When you make the `total_score` column, pay close attention to it. If you notice the problem, fix it.
#
# **BONUS:** You don't need these columns to be numbers, but life would be better if they were.

# %%
scifi = pd.read_csv('C:/Users/ilias/Documents/LEDE_COLUMBIA_J_SCHOOL/Foundations/Assignments/Class-10/Homework-10/scraped/sci-fi.csv')

# %%
scifi['title'] = scifi['title'].str.strip()

# %%
scifi['full_score'] = scifi['full_score'].str.strip()

# %%
scifi.head()
# Out:
#                             full_rating  \
# 0     4.07 avg rating — 785,502 ratings
# 1   4.34 avg rating — 5,212,935 ratings
# 2     3.76 avg rating — 922,308 ratings
# 3     4.04 avg rating — 702,272 ratings
# 4      4.06 avg rating — 77,664 ratings
#
#                                             full_score  rank  \
# 0  score: 28,539,\n              and\n292 people voted     1
# 1  score: 27,566,\n              and\n282 people voted     2
# 2  score: 20,049,\n              and\n205 people voted     3
# 3  score: 17,684,\n              and\n185 people voted     4
# 4  score: 16,070,\n              and\n165 people voted     5
#
#                                                title  \
# 0                                The Handmaid's Tale
# 1            The Hunger Games (The Hunger Games, #1)
# 2             Frankenstein, or The Modern Prometheus
# 3  A Wrinkle in Time (A Wrinkle in Time Quintet, #1)
# 4                          The Left Hand of Darkness
#
#                                                       url
# 0                    /book/show/38447.The_Handmaid_s_Tale
# 1                     /book/show/2767052-the-hunger-games
# 2  /book/show/18490.Frankenstein_or_The_Modern_Prometheus
# 3                      /book/show/18131.A_Wrinkle_in_Time
# 4              /book/show/18423.The_Left_Hand_of_Darkness

# %%
scifi['full_rating'].dtype
# Out:
# dtype('O')

# %%
scifi['series'] = scifi['title'].str.extract(r"[(](.*)[)]")
scifi['series']
# Out:
# 0                                   NaN
# 1                  The Hunger Games, #1
# 2                                   NaN
# 3         A Wrinkle in Time Quintet, #1
# 4                                   NaN
# 5                         Divergent, #1
# 6                  The Hunger Games, #2
# 7                         The Giver, #1
# 8                                   NaN
# 9                                   NaN
# 10                        MaddAddam, #1
# 11                 The Hunger Games, #3
# 12                                  NaN
# 13               Oxford Time Travel, #1
# 14                                  NaN
# 15                      The Sparrow, #1
# 16                  Vorkosigan Saga, #1
# 17                   Imperial Radch, #1
# 18             Dragonriders of Pern, #1
# 19                        Earthseed, #1
# 20               Oxford Time Travel, #2
# 21                  Vorkosigan Saga, #2
# 22                  Vorkosigan Saga, #7
# 23                         The Host, #1
# 24                        Divergent, #2
# 25                                  NaN
# 26                 Vorkosigan Saga, #10
# 27                  Aurora Rhapsody, #1
# 28                   Crystal Singer, #1
# 29                        MaddAddam, #2
#                     ...
# 70       Species Intervention #6609, #4
# 71                                  NaN
# 72       Species Intervention #6609, #1
# 73                                  NaN
# 74                     Machinations, #1
# 75                                  NaN
# 76       Species Intervention #6609, #5
# 77                  Aurora Rhapsody, #2
# 78                 Vorkosigan Saga, #14
# 79                  Patternmaster, #1-4
# 80       Species Intervention #6609, #6
# 81                         Darkover, #1
# 82       Species Intervention #6609, #2
# 83    The Men of Space Station One, #10
# 84                         Delirium, #1
# 85                    Sea-anan Saga, #2
# 86     The Men of Space Station One, #2
# 87                                  NaN
# 88                                  NaN
# 89                                  NaN
# 90                     Sirantha Jax, #1
# 91                                  NaN
# 92                        Temeraire, #1
# 93     The Men of Space Station One, #5
# 94                        Foreigner, #3
# 95                        Foreigner, #2
# 96              Across the Universe, #1
# 97                    Sea-anan Saga, #1
# 98     The Men of Space Station One, #4
# 99                                  NaN
# Name: series, Length: 100, dtype: object

# %%
scifi['series_no'] = scifi['series'].str.extract(r"#(\d+)\b")
scifi['series_no']
# Out:
# 0      NaN
# 1        1
# 2      NaN
# 3        1
# 4      NaN
# 5        1
# 6        2
# 7        1
# 8      NaN
# 9      NaN
# 10       1
# 11       3
# 12     NaN
# 13       1
# 14     NaN
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       2
# 21       2
# 22       7
# 23       1
# 24       2
# 25     NaN
# 26      10
# 27       1
# 28       1
# 29       2
#       ...
# 70    6609
# 71     NaN
# 72    6609
# 73     NaN
# 74       1
# 75     NaN
# 76    6609
# 77       2
# 78      14
# 79       1
# 80    6609
# 81       1
# 82    6609
# 83      10
# 84       1
# 85       2
# 86       2
# 87     NaN
# 88     NaN
# 89     NaN
# 90       1
# 91     NaN
# 92       1
# 93       5
# 94       3
# 95       2
# 96       1
# 97       1
# 98       4
# 99     NaN
# Name: series_no, Length: 100, dtype: object

# %%
scifi['score_votes'] = scifi['full_score'].str.extract(r"and\n(\d+)\speople")
scifi['score_votes']
# Out:
# 0     292
# 1     282
# 2     205
# 3     185
# 4     165
# 5     134
# 6     128
# 7     117
# 8     107
# 9     104
# 10    102
# 11    100
# 12     88
# 13     88
# 14     81
# 15     69
# 16     68
# 17     70
# 18     68
# 19     64
# 20     64
# 21     61
# 22     54
# 23     53
# 24     54
# 25     48
# 26     48
# 27     45
# 28     47
# 29     46
#      ...
# 70     19
# 71     20
# 72     19
# 73     22
# 74     17
# 75     22
# 76     18
# 77     18
# 78     24
# 79     19
# 80     17
# 81     19
# 82     17
# 83     16
# 84     16
# 85     16
# 86     16
# 87     18
# 88     15
# 89     18
# 90     15
# 91     16
# 92     16
# 93     14
# 94     16
# 95     16
# 96     13
# 97     13
# 98     13
# 99     16
# Name: score_votes, Length: 100, dtype: object

# %%
scifi['total_score'] = scifi['full_score'].str.extract(r"^score: (.*),\n")                      
#score: 28,539,\n and\n292 people voted
scifi['total_score']
# Out:
# 0     28,539
# 1     27,566
# 2     20,049
# 3     17,684
# 4     16,070
# 5     12,935
# 6     12,261
# 7     11,238
# 8     10,246
# 9      9,907
# 10     9,628
# 11     9,423
# 12     8,250
# 13     8,175
# 14     7,523
# 15     6,571
# 16     6,418
# 17     6,257
# 18     6,238
# 19     5,999
# 20     5,933
# 21     5,698
# 22     5,046
# 23     5,012
# 24     4,899
# 25     4,413
# 26     4,398
# 27     4,394
# 28     4,249
# 29     4,245
#        ...
# 70     1,817
# 71     1,775
# 72     1,772
# 73     1,740
# 74     1,698
# 75     1,692
# 76     1,687
# 77     1,684
# 78     1,683
# 79     1,575
# 80     1,565
# 81     1,564
# 82     1,559
# 83     1,495
# 84     1,461
# 85     1,458
# 86     1,455
# 87     1,420
# 88     1,380
# 89     1,323
# 90     1,316
# 91     1,301
# 92     1,285
# 93     1,278
# 94     1,240
# 95     1,197
# 96     1,174
# 97     1,170
# 98     1,169
# 99     1,155
# Name: total_score, Length: 100, dtype: object

# %%
scifi['rating_count'] = scifi['full_rating'].str.extract(r"—\s(.*)\sratings")
scifi['rating_count']
# Out:
# 0       785,502
# 1     5,212,935
# 2       922,308
# 3       702,272
# 4        77,664
# 5     2,345,974
# 6     2,049,239
# 7     1,379,452
# 8        57,605
# 9        53,473
# 10      176,024
# 11    1,932,930
# 12    1,355,662
# 13       38,534
# 14       36,316
# 15       46,116
# 16       22,554
# 17       53,063
# 18      106,206
# 19       31,668
# 20       26,705
# 21       18,831
# 22       20,045
# 23      793,665
# 24      979,341
# 25       33,313
# 26       12,743
# 27        1,466
# 28       16,555
# 29       81,801
#         ...
# 70          336
# 71      206,616
# 72          799
# 73        4,568
# 74          215
# 75        8,590
# 76          256
# 77          748
# 78       10,873
# 79        3,203
# 80          244
# 81        5,588
# 82          367
# 83           93
# 84      366,089
# 85           56
# 86          134
# 87        3,160
# 88        4,504
# 89        9,782
# 90       11,925
# 91        3,338
# 92       57,864
# 93          116
# 94        3,328
# 95        3,717
# 96      103,428
# 97           97
# 98          111
# 99        3,244
# Name: rating_count, Length: 100, dtype: object

# %%
scifi['avg_rating'] = scifi['full_rating'].str.extract(r"(\d\.\d\d)\sa")
scifi['avg_rating']
# Out:
# 0     4.07
# 1     4.34
# 2     3.76
# 3     4.04
# 4     4.06
# 5     4.23
# 6     4.30
# 7     4.12
# 8     4.19
# 9     4.20
# 10    4.00
# 11    4.03
# 12    3.95
# 13    4.03
# 14    4.10
# 15    4.17
# 16    4.12
# 17    3.97
# 18    4.10
# 19    4.14
# 20    4.13
# 21    4.29
# 22    4.31
# 23    3.84
# 24    4.06
# 25    3.69
# 26    4.44
# 27    3.88
# 28    4.08
# 29    4.06
#       ...
# 70    4.41
# 71    4.02
# 72    3.83
# 73    3.55
# 74    3.78
# 75    4.01
# 76    4.46
# 77    4.18
# 78    4.05
# 79    4.32
# 80    4.48
# 81    3.88
# 82    4.19
# 83    4.28
# 84    3.99
# 85    4.91
# 86    3.86
# 87    4.04
# 88    4.01
# 89    3.91
# 90    3.74
# 91    4.03
# 92    4.05
# 93    3.82
# 94    4.19
# 95    4.17
# 96    3.78
# 97    4.16
# 98    3.85
# 99    3.83
# Name: avg_rating, Length: 100, dtype: object

# %%
scifi.to_csv("sci-fi_cleaned.csv", index=False)

# %% [markdown]
# ## 1.3 Where you're just doing one of my former students' projects
#
# Once upon a time my student Stefan did a project that involved some lawyer stuff. Most of the content was in PDFs, though! I converted them to text files and put them into the `pdfs` folder, and gave you code below to open up each of them and save their contents into a dataframe.
#
# What a nice dataframe! I want you to add the following columns to it:
#
# * `lawyer_app`, the applicant's lawyer (pro se means that they did it themselves, that's fine)
# * `lawyer_gov`, the government's lawyer
# * `judge`, the name of the judge
# * `access`, whether the clearance is granted or denied (although you might miss a few)
#
# Save as **court_cleaned.csv**.
#
# **Note:** You can look at the original PDFs, they're also included.
#
# **Note:** This uses a fun utility called `glob`, which is mostly fun because you use it as `glob.glob`. It's used to find files that match a certain filename pattern.
#
# **BONUS:** You'll be happy once you get the judge, but make sure it doesn't have any extra punctuation on it.
#
# **BONUS:** You can for some words using `.str.contains("blah")` and save it into new columns. Maybe `has_debt`, `has_bankruptcy`, etc.
#
# > It's okay if it isn't perfect. Converting PDF into data rarely is! Usually you get 90% of it done with computers, then send people to enter the other 10% by hand.

# %%
import glob
filenames = glob.glob("pdfs/*.txt")
files = [open(filename, encoding = "utf8").read() for filename in filenames]
df = pd.DataFrame({'filename': filenames, 'content': files})

# %%
df.content[0]
# Out:
# "                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\n \n\nCOACHER, Robert E., Administrative Judge: \n\n \nApplicant has not mitigated the alcohol consumption security concerns. Eligibility \n\nfor access to classified information is denied.  \n\nStatement of the Case \n\nOn  June  16,  2015,  the  Department  of  Defense  Consolidated  Adjudications \nFacility (DOD CAF) issued Applicant a Statement of Reasons (SOR) detailing security \nconcerns  under  Guideline  G,  alcohol  consumption.  DOD  CAF  acted  under  Executive \nOrder  (EO)  10865,  Safeguarding  Classified  Information  within  Industry  (February  20, \n1960),  as  amended;  DOD  Directive  5220.6,  Defense  Industrial  Personnel  Security \nClearance  Review  Program  (January  2,  1992),  as  amended  (Directive);  and  the \nadjudicative guidelines (AG) effective within the DOD on September 1, 2006. \n\n \nApplicant  answered  the  SOR  on  July  14,  2015,  and  elected  to  have  his  case \ndecided on the written record in lieu of a hearing. Department Counsel submitted the \nGovernment’s File of Relevant Material (FORM) on September 9, 2015. The evidence \n\n) \n) \n) \n) \n) \n) \n \n \n\n \n \n\n \n1 \n \n \n\n\x0cincluded in the FORM is identified as Items 4-10 and is admitted into the record (Items \n1-3 are pleadings and transmittal documents). The FORM was mailed to Applicant, who \nreceived it on October 19, 2015. Applicant was given an opportunity to file objections \nand submit material in refutation, extenuation, or mitigation. He submitted an undated \nresponse to the FORM, which was admitted without objection as Applicant Exhibit (AE) \nA. The case was assigned to me on December 21, 2015.  \n\nIn Applicant’s answer to the SOR, he admitted all but one of the allegations. The \nadmissions are adopted as findings of fact. After a careful review of the pleadings and \nevidence, I make the following additional findings of fact.1 \n\n \nApplicant is 56 years old. He has worked for a defense contractor since 1997. He \nis divorced and has three children, ages 15, 18, and 20. He has a bachelor’s degree. He \nhas no military experience.2  \n \n \n \nApplicant’s conduct raised in the SOR included: a history of consuming alcohol, \nat times, to excess from 1974 to about April 2014; being found guilty for operating under \nthe  influence  of  alcohol  (OUI)  in  February  1991;  being  found  guilty  for  OUI  2nd  in \nNovember 1997; and being found guilty for OUI 3rd in November 2010 (See SOR ¶¶ 1.a \n- 1.d).3 \n \n \nApplicant  began  drinking  alcohol  when  he  was  approximately  15  years  old  in \n1974. He drinks beer on most occasions. Even after his OUI convictions, he stated he \nwas  still  was  consuming  two  to  three  beers  a  week.  He  drinks  in  social  settings  and \nafter hockey games. As a result of his 2010 OUI conviction, he lost his driver’s license \nfor five years. He completed his probation in May 2015.4 \n \n \nCourt documents establish that Applicant was found guilty of three OUI offenses, \nin 1992 (1991 arrest), 2000 (1997 arrest), and 2012 (2010 arrest). He was placed on \nprobation in each instance.5 \n \n \nIn  February  1991,  Applicant  was  driving  home  from  a  friend’s  house  where  he \nconsumed  about  four  beers.  He  was  stopped  by  a  police  officer  who  had  observed \nApplicant’s  car  cross  over  the  center  line.  Applicant  was  given,  and  failed,  a  field \nsobriety test. He was taken into the police station where he refused a breathalyzer test. \n    ...

# %% [markdown]
# Okay, now do the work and **make those new columns!**

# %%
df['lawyer_app'] = df.content.str.extract(r"For Applicant[:]*[\n ]*(.*).*", re.IGNORECASE)  
df.head()
# Out:
#                    filename  \
# 0  pdfs\11-02438.h1.pdf.txt
# 1  pdfs\11-03073.h1.pdf.txt
# 2  pdfs\11-04909.h1.pdf.txt
# 3  pdfs\11-07728.h1.pdf.txt
# 4  pdfs\11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                content  \
# 0                                                                \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\...
# 1                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 2                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 3     DEPARTMENT OF DEFENSE \n\n       DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance  \n\n------------------------    \n \n\n \n\nISCR Case No. 11-07728 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n\n \n \n\nAppearances \n\n___________ \n\n \nDecision \n\n___________ \n\nFor Government: Julie R. Mendez, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\n \n\nHARVEY, Mark, Administrative Judge: \n \...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...
#
#             lawyer_app
# 0              Pro se
# 1  Mark S. Zaid, Esq.
# 2              Pro se
# 3  Mark S. Zaid, Esq.
# 4              Pro se

# %%
df['lawyer_gov'] = df.content.str.extract(r"For Government[:]*[\n ]*(.*), Esq\w*", re.IGNORECASE)  
df.head()
# Out:
#                    filename  \
# 0  pdfs\11-02438.h1.pdf.txt
# 1  pdfs\11-03073.h1.pdf.txt
# 2  pdfs\11-04909.h1.pdf.txt
# 3  pdfs\11-07728.h1.pdf.txt
# 4  pdfs\11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                content  \
# 0                                                                \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\...
# 1                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 2                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 3     DEPARTMENT OF DEFENSE \n\n       DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance  \n\n------------------------    \n \n\n \n\nISCR Case No. 11-07728 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n\n \n \n\nAppearances \n\n___________ \n\n \nDecision \n\n___________ \n\nFor Government: Julie R. Mendez, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\n \n\nHARVEY, Mark, Administrative Judge: \n \...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...
#
#             lawyer_app           lawyer_gov
# 0              Pro se     Stephanie C. Hess
# 1  Mark S. Zaid, Esq.   Robert J. Kilmartin
# 2              Pro se       Richard Stevens
# 3  Mark S. Zaid, Esq.       Julie R. Mendez
# 4              Pro se       Julie R. Mendez

# %%
df['judge'] = df.content.str.extract(r"\n(.*)Administrative Judge:", re.IGNORECASE)  
df.head()
# Out:
#                    filename  \
# 0  pdfs\11-02438.h1.pdf.txt
# 1  pdfs\11-03073.h1.pdf.txt
# 2  pdfs\11-04909.h1.pdf.txt
# 3  pdfs\11-07728.h1.pdf.txt
# 4  pdfs\11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                content  \
# 0                                                                \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\...
# 1                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 2                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 3     DEPARTMENT OF DEFENSE \n\n       DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance  \n\n------------------------    \n \n\n \n\nISCR Case No. 11-07728 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n\n \n \n\nAppearances \n\n___________ \n\n \nDecision \n\n___________ \n\nFor Government: Julie R. Mendez, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\n \n\nHARVEY, Mark, Administrative Judge: \n \...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...
#
#             lawyer_app           lawyer_gov                       judge
# 0              Pro se     Stephanie C. Hess        COACHER, Robert E.,
# 1  Mark S. Zaid, Esq.   Robert J. Kilmartin       LOUGHRAN, Edward W.,
# 2              Pro se       Richard Stevens           DUFFY, James F.,
# 3  Mark S. Zaid, Esq.       Julie R. Mendez              HARVEY, Mark,
# 4              Pro se       Julie R. Mendez  MARSHALL, Jr., Arthur E.,

# %%
df['access'] = df.content.str.extract(r"[access|clearance] .* (denied|granted)", re.IGNORECASE)  
df.head()
# Out:
#                    filename  \
# 0  pdfs\11-02438.h1.pdf.txt
# 1  pdfs\11-03073.h1.pdf.txt
# 2  pdfs\11-04909.h1.pdf.txt
# 3  pdfs\11-07728.h1.pdf.txt
# 4  pdfs\11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                content  \
# 0                                                                \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\...
# 1                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 2                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 3     DEPARTMENT OF DEFENSE \n\n       DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance  \n\n------------------------    \n \n\n \n\nISCR Case No. 11-07728 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n\n \n \n\nAppearances \n\n___________ \n\n \nDecision \n\n___________ \n\nFor Government: Julie R. Mendez, Esq., Department Counsel \n\nFor Applicant: Mark S. Zaid, Esq. \n\n \n\nHARVEY, Mark, Administrative Judge: \n \...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...
#
#             lawyer_app           lawyer_gov                       judge  \
# 0              Pro se     Stephanie C. Hess        COACHER, Robert E.,
# 1  Mark S. Zaid, Esq.   Robert J. Kilmartin       LOUGHRAN, Edward W.,
# 2              Pro se       Richard Stevens           DUFFY, James F.,
# 3  Mark S. Zaid, Esq.       Julie R. Mendez              HARVEY, Mark,
# 4              Pro se       Julie R. Mendez  MARSHALL, Jr., Arthur E.,
#
#     access
# 0   denied
# 1  granted
# 2  granted
# 3  granted
# 4   denied

# %% [markdown]
# # Reading books
#
# When you're doing text work, you're legally obligated work on Jane Austen's Pride and Prejudice (at least I *think* so). Let's do some naive analysis of it!
#
# ## Read in Jane Austen's Pride and Prejudice (without moving the file!)
#
# It's in the `data/` directory, and named `Austen_Pride.txt`.

# %%
book = open("data/Austen_Pride.txt").read()

# %% [markdown]
# ## Look at the first 500 or so characters of it

# %%
book[0:500]
# Out:
# ' Pride and Prejudice\nby Jane Austen\nChapter 1\nIt is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.\nHowever little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.\n"My dear Mr. Bennet," said his lady to him one day, "have you heard that Nethe'

# %% [markdown]
# ## Use a regular expression to find every "he" or "she" in the book. There should be about 3000 of them.
#
# **Tip:** Do you know about **word boundaries?** `\b` means "the beginning of end of a word."
#
# **Tip:** You might also want to use `re.IGNORECASE`. Maybe you'll need to google it?
#
# **Tip:** Do NOT use `re.compile`

# %%
len(re.findall(r"[\n ]+he\b|[\n ]+she\b", book, re.IGNORECASE))
# Out:
# 2990

# %% [markdown]
# ## Use a regular expression to find those same "he" or "she"s, but also match *the word after it*
#
# The first four should be:
#
# * he is
# * he had
# * she told
# * he came

# %%
re.findall(r"[\n ]+he \w*|[\n ]+she* \w*", book, re.IGNORECASE)
# Out:
# [' he is',
#  ' he had',
#  ' she told',
#  ' he came',
#  ' he agreed',
#  ' he is',
#  ' he married',
#  ' he may',
#  ' he comes',
#  ' she ought',
#  ' he comes',
#  ' he chooses',
#  ' she is',
#  ' She was',
#  ' she was',
#  ' she fancied',
#  ' He had',
#  ' he should',
#  ' she had',
#  ' he suddenly',
#  ' She has',
#  ' She is',
#  ' she will',
#  ' she will',
#  ' he continued',
#  ' he wished',
#  ' she began',
#  ' she had',
#  ' he spoke',
#  ' he left',
#  ' he would',
#  ' he eluded',
#  ' He was',
#  ' he meant',
#  ' He had',
#  ' he had',
#  ' he saw',
#  ' he wore',
#  ' She could',
#  ' he could',
#  ' she began',
#  ' he might',
#  ' he ought',
#  ' he brought',
#  ' he had',
#  ' he was',
#  ' he was',
#  ' he was',
#  ' he was',
#  ' He was',
#  ' he would',
#  ' She is',
#  ' he looked',
#  ' he withdrew',
#  ' She told',
#  ' she had',
#  ' she had',
#  ' he was',
#  ' he had',
#  ' He had',
#  ' he ',
#  ' he had',
#  ' she entered',
#  ' she looked',
#  ' he actually',
#  ' she was',
#  ' he asked',
#  ' he asked',
#  ' he did',
#  ' he seemed',
#  ' she was',
#  ' he inquired',
#  ' she was',
#  ' he danced',
#  ' he had',
#  ' he had',
#  ' He is',
#  ' she was',
#  ' She was',
#  ' she added',
#  ' he is',
#  ' He walked',
#  ' he walked',
#  ' she admired',
#  ' he possibly',
#  ' He could',
#  ' he certainly',
#  ' she was',
#  ' he was',
#  ' he might',
#  ' he was',
#  ' he was',
#  ' He did',
#  ' he never',
#  ' He was',
#  ' he appeared',
#  ' he had',
#  ' he could',
#  ' he had',
#  ' he acknowledged',
#  ' she smiled',
#  ' he chose',
#  ' he had',
#  ' he had',
#  ' he could',
#  ' he was',
#  ' he seemed',
#  ' he danced',
#  ' he admired',
#  ' he _did_',
#  ' he liked',
#  ' he did',
#  ' he thought',
#  ' he is',
#  ' he sat',
#  ' she asked',
#  ' he liked',
#  ' he could',
#  ' she said',
#  ' he seemed',
#  ' he never',
#  ' he is',
#  ' he had',
#  ' he would',
#  ' he is',
#  ' he had',
#  ' he had',
#  ' he has',
#  ' he had',
#  ' she should',
#  ' she continued',
#  ' she would',
#  ' he did',
#  ' she had',
#  ' she considered',
#  ' She mentioned',
#  ' she may',
#  ' she feels',
#  ' he may',
#  ' she does',
#  ' she does',
#  ' he must',
#  ' he does',
#  ' he must',
#  ' he must',
#  ' he sees',
#  ' she can',
#  ' she is',
#  ' she chooses',
#  ' she is',
#  ' she cannot',
#  ' She has',
#  ' She danced',
#  ' she saw',
#  ' she merely',
#  ' she might',
#  ' he had',
#  ' she were',
#  ' she had',
#  ' she were',
#  ' she was',
#  ' he had',
#  ' he looked',
#  ' he made',
#  ' she hardly',
#  ' he began',
#  ' he had',
#  ' he was',
#  ' he was',
#  ' she was',
#  ' he was',
#  '\nHe began',
#  ' she to',
#  ' he does',
#  ' he is',
#  ' He has',
#  ' she turned',
#  ' she added',
#  ' she could',
#  ' she would',
#  ' she was',
#  ' she had',
#  ' he continued',
#  '\nHe paused',
#  ' he was',
#  ' he would',
#  ' she instantly',
#  ' he can',
#  ' he was',
#  ' he would',
#  ' she been',
#  ' she will',
#  '\nHe listened',
#  ' she chose',
#  '\nShe had',
#  ' he was',
#  ' she sees',
#  ' she was',
#  ' he say',
#  '\nShe did',
#  ' she was',
#  ' she should',
#  ' She will',
#  ' she stays',
#  ' she was',
#  ' She declared',
#  ' he goes',
#  '\nShe was',
#  ' she should',
#  ' She was',
#  ' she longed',
#  ' She was',
#  ' she was',
#  ' she saw',
#  ' she had',
#  ' she must',
#  ' she only',
#  ' she had',
#  ' she could',
#  ' she could',
#  ' she believed',
#  ' she was',
#  ' She had',
#  ' he was',
#  ' he found',
#  ' she returned',
#  ' she was',
#  ' she had',
#  ' She really',
#  ' she be',
#  ' she came',
#  ' she mean',
#  ' he replied',
#  ' she is',
#  ' she were',
#  ' She was',
#  ' she had',
#  ' she should',
#  ' she found',
#  ' she declined',
#  ' she would',
#  ' she could',
#  ' She is',
#  ' He immediately',
#  ' she could',
#  ' he replied',
#  ' she drew',
#  ' she be',
#  ' she will',
#  ' She is',
#  ' she was',
#  ' she must',
#  ' she must',
#  ' she must',
#  ' she could',
#  ' she would',
#  ' she was',
#  ' he could',
#  ' she very',
#  ' she requested',
#  ' she found',
#  ' she had',
#  ' She would',
#  ' she expected',
#  ' she remains',
#  ' she added',
#  ' she is',
#  ' she has',
#  ' she had',
#  ' he replied',
#  ' He only',
#  ' she called',
#  ' He had',
#  ' she would',
#  ' she was',
#  ' she is',
#  ' she is',
#  ' she was',
#  ' he would',
#  ' he did',
#  ' he thought',
#  ' he wrote',
#  ' She longed',
#  ' She performed',
#  ' She had',
#  ' She was',
#  ' he did',
#  ' she is',
#  ' she added',
#  ' he does',
#  '\nHe made',
#  '\nHe was',
#  ' he does',
#  ' He studies',
#  ' He leaves',
#  ' he did',
#  ' he would',
#  ' he has',
#  ' she could',
#  ' he was',
#  ' he had',
#  ' he applied',
#  ' she seated',
#  ' she turned',
#  ' She hardly',
#  ' she could',
#  ' he should',
#  ' he disliked',
#  ' She could',
#  ' she drew',
#  ' She liked',
#  '\nShe smiled',
#  ' He repeated',
#  ' he was',
#  ' He really',
#  ' he should',
#  '\nShe often',
#  ' she left',
#  '\nShe then',
#  ' she rambled',
#  ' she was',
#  ' she had',
#  ' he had',
#  ' He addressed',
#  ' he was',
#  ' He was',
#  ' she should',
#  ' she removed',
#  ' she might',
#  ' He then',
#  ' She had',
#  ' She assured',
#  ' she was',
#  ' She could',
#  ' he merely',
#  ' she had',
#  ' she gave',
#  ' She then',
#  ' she turned',
#  ' he chooses',
#  ' she replied',
#  ' she got',
#  ' she walked',
#  ' she resolved',
#  ' He was',
#  ' He was',
#  ' he declined',
#  ' he could',
#  ' he mean',
#  ' She was',
#  ' she could',
#  ' he means',
#  ' she allowed',
#  ' he may',
#  ' He owns',
#  ' he replied',
#  ' she had',
#  ' He began',
#  ' she was',
#  ' she could',
#  ' she much',
#  ' she urged',
#  ' she had',
#  ' she was',
#  ' she felt',
#  ' She attracted',
#  ' he liked',
#  ' He wisely',
#  ' he scarcely',
#  ' he adhered',
#  ' she even',
#  ' he had',
#  ' she often',
#  ' he had',
#  ' he thus',
#  ' he pleases',
#  ' she continued',
#  ' he not',
#  ' he does',
#  ' he folded',
#  ' he says',
#  ' he is',
#  ' he can',
#  ' he thinks',
#  ' he mean',
#  ' he would',
#  ' he could',
#  ' he be',
#  ' she was',
#  ' He was',
#  ' He had',
#  ' he complimented',
#  ' he had',
#  ' he did',
#  '\nHe was',
#  ' he begged',
#  ' he was',
#  ' He begged',
#  ' she declared',
#  ' he continued',
#  ' he thought',
#  ' he expected',
#  ' he seemed',
#  ' he protested',
#  ' he had',
#  ' She had',
#  ' he had',
#  ' She had',
#  ' he knew',
#  ' he had',
#  ' She had',
#  ' she would',
#  ' she made',
#  ' She had',
#  ' he could',
#  ' he chose',
#  ' she had',
#  ' he had',
#  ' she is',
#  ' she live',
#  ' she was',
#  ' she any',
#  ' she is',
#  ' she handsome',
#  ' She is',
#  ' she could',
#  ' she is',
#  ' she been',
#  ' he had',
#  ' he listened',
#  ' he started',
#  ' he never',
#  ' he chose',
#  ' he opened',
#  ' he had',
#  ' she interrupted',
#  ' he does',
#  ' he offered',
#  ' he acted',
#  ' he would',
#  ' he bore',
#  ' he belonged',
#  ' he had',
#  ' he felt',
#  ' he intended',
#  ' he had',
#  ' he meant',
#  ' he found',
#  ' he thought',
#  ' she was',
#  ' he had',
#  ' she could',
#  ' she did',
#  ' she must',
#  ' she might',
#  ' she could',
#  ' he would',
#  ' he had',
#  ' he told',
#  ' he was',
#  ' he bowed',
#  ' he could',
#  ' he was',
#  ' he had',
#  ' He was',
#  ' he said',
#  ' she was',
#  ' she should',
#  ' she had',
#  ' She received',
#  ' he returned',
#  ' he could',
#  ' she could',
#  ' he was',
#  ' She had',
#  ' she said',
#  ' he walked',
#  ' she had',
#  ' she could',
#  ' He protested',
#  ' he had',
#  ' she had',
#  ' he supposed',
#  ' he had',
#  ' he was',
#  ' he declared',
#  ' he might',
#  ' she had',
#  ' she felt',
#  ' he was',
#  ' he found',
#  ' she heard',
#  ' she could',
#  ' she had',
#  ' he finally',
#  ' he immediately',
#  ' he certainly',
#  ' he had',
#  ' he had',
#  ' he received',
#  ' she was',
#  ' she soon',
#  ' she was',
#  ' she chiefly',
#  ' she could',
#  ' She dared',
#  ' He inquired',
#  ' He is',
#  ' he or',
#  ' he chooses',
#  ' he is',
#  ' he wishes',
#  ' he must',
#  ' he is',
#  ' he had',
#  ' he added',
#  ' He was',
#  ' He meant',
#  ' he had',
#  ' he hates',
#  ' He deserves',
#  ' he will',
#  ' he expressed',
#  ' He had',
#  ' she continued',
#  ' She could',
#  ' she contented',
#  ' he gave',
#  ' He was',
#  ' he felt',
#  ' he should',
#  ' he is',
#  ' He has',
#  '\nHe shook',
#  ' she is',
#  ' she was',
#  ' she is',
#  ' She is',
#  ' He cannot',
#  ' he chooses',
#  ' He does',
#  ' He can',
#  ' he thinks',
#  ' he is',
#  ' he is',
#  ' he is',
#  ' he had',
#  ' he assured',
#  ' he considered',
#  ' she would',
#  ' he asked',
#  ' she replied',
#  ' he certainly',
#  ' she is',
#  ' she and',
#  ' she thought',
#  ' he were',
#  ' he has',
#  ' she is',
#  ' She has',
#  ' she derives',
#  ' he had',
#  ' he said',
#  ' he did',
#  ' She could',
#  ' he had',
#  ' she had',
#  ' she had',
#  ' he did',
#  ' he crowded',
#  ' he could',
#  ' she knew',
#  ' he gave',
#  ' he had',
#  ' she had',
#  ' he was',
#  ' she had',
#  ' she did',
#  ' she could',
#  ' he intended',
#  ' he did',
#  ' he would',
#  ' she was',
#  ' he entertained',
#  ' She had',
#  ' she could',
#  ' She was',
#  ' she was',
#  ' she observed',
#  ' he did',
#  ' She had',
#  ' he had',
#  ' she could',
#  ' he directly',
#  ' She was',
#  ' she could',
#  ' she had',
#  ' she was',
#  '\nShe danced',
#  ' he was',
#  ' she returned',
#  ' she found',
#  ' she did',
#  ' she accepted',
#  ' He walked',
#  ' she was',
#  ' she was',
#  ' she began',
#  ' she made',
#  ' He replied',
#  ' she addressed',
#  '\nHe smiled',
#  ' she wished',
#  '\nHe made',
#  ' he asked',
#  ' she and',
#  ' She answered',
#  ' he said',
#  ' he may',
#  ' he is',
#  ' he stopped',
#  ' he turned',
#  ' she replied',
#  ' she said',
#  '\nShe shook',
#  ' he gravely',
#  ' he coldly',
#  ' She said',
#  ' he was',
#  ' he has',
#  ' he cannot',
#  ' he could',
#  ' he was',
#  ' he had',
#  ' \nhe could',
#  ' he informed',
#  ' She then',
#  ' she was',
#  ' he will',
#  ' he has',
#  ' he has',
#  ' he never',
#  ' he has',
#  ' he say',
#  ' he has',
#  ' he believes',
#  ' he is',
#  '\nShe then',
#  ' she had',
#  ' he had',
#  ' he will',
#  ' she ceased',
#  ' he left',
#  ' she eagerly',
#  ' she could',
#  ' she felt',
#  ' he only',
#  ' He answered',
#  ' he was',
#  ' she could',
#  ' she turned',
#  ' She saw',
#  ' she felt',
#  ' she plainly',
#  ' she determined',
#  ' she might',
#  ' she considered',
#  ' she vexed',
#  ' she could',
#  ' she might',
#  ' she liked',
#  ' She concluded',
#  ' she could',
#  ' he may',
#  ' she could',
#  ' She could',
#  ' she dreaded',
#  ' he was',
#  ' she was',
#  ' she saw',
#  ' she had',
#  ' she endeavour',
#  ' she began',
#  ' she watched',
#  ' she might',
#  ' She looked',
#  ' she bore',
#  ' She looked',
#  ' She looked',
#  ' He took',
#  ' he must',
#  ' He must',
#  ' he cannot',
#  ' he should',
#  ' he owes',
#  ' he concluded',
#  ' he was',
#  ' she think',
#  ' he must',
#  ' she could',
#  ' She was',
#  ' he could',
#  ' she entreat',
#  ' He assured',
#  ' he was',
#  ' he should',
#  ' She owed',
#  '\nShe was',
#  ' he never',
#  ' She felt',
#  ' he would',
#  ' he readily',
#  ' he was',
#  ' she should',
#  ' she thought',
#  ' he set',
#  ' he supposed',
#  ' he addressed',
#  ' she can',
#  ' she was',
#  ' He can',
#  ' she added',
#  ' she sat',
#  ' she could',
#  ' he allowed',
#  ' he continued',
#  ' she condescended',
#  ' she said',
#  ' she cried',
#  ' he first',
#  ' she would',
#  ' she thus',
#  ' she would',
#  ' he persisted',
#  ' she entered',
#  ' he trusted',
#  ' he had',
#  ' she would',
#  ' she dared',
#  ' she added',
#  ' She is',
#  ' she is',
#  ' she would',
#  ' she actually',
#  ' she could',
#  ' she is',
#  '\nShe would',
#  ' she entered',
#  ' she vows',
#  ' she will',
#  ' he will',
#  ' she entered',
#  ' she had',
#  ' she will',
#  ' he will',
#  ' She shall',
#  ' she appeared',
#  ' she wished',
#  ' She talked',
#  ' She endeavoured',
#  ' He thought',
#  ' he suffered',
#  ' She was',
#  ' she will',
#  ' she likewise',
#  ' she added',
#  ' she comes',
#  ' she can',
#  ' She talked',
#  ' she said',
#  ' she could',
#  ' he presently',
#  ' He scarcely',
#  ' he had',
#  ' He was',
#  ' he meant',
#  ' He joined',
#  ' he voluntarily',
#  '\nShe highly',
#  ' he particularly',
#  ' she felt',
#  ' she read',
#  ' he and',
#  ' he companion',
#  ' she says',
#  '\nShe then',
#  ' she saw',
#  ' she was',
#  ' she is',
#  ' he imagined',
#  ' he will',
#  ' he may',
#  ' he comes',
#  ' he should',
#  ' He is',
#  ' she inspires',
#  ' he will',
#  ' she finished',
#  ' she is',
#  ' she suspects',
#  ' she means',
#  ' She follows',
#  ' he does',
#  ' She is',
#  ' she have',
#  ' she would',
#  ' she is',
#  ' she may',
#  ' he is',
#  ' he took',
#  ' he is',
#  ' she is',
#  ' he returns',
#  ' she could',
#  '\nShe represented',
#  ' she felt',
#  ' she was',
#  ' she bewailed',
#  ' she had',
#  ' he had',
#  ' she would',
#  ' she would',
#  ' he had',
#  ' she did',
#  ' He was',
#  ' he was',
#  ' he was',
#  ' he walked',
#  ' she dared',
#  ' he earnestly',
#  ' he was',
#  ' he and',
#  ' She had',
#  ' he would',
#  ' she had',
#  ' she felt',
#  ' she valued',
#  ' She resolved',
#  ' he returned',
#  ' he was',
#  ' he was',
#  ' he was',
#  ' he replied',
#  ' he meditated',
#  ' he thought',
#  ' She rated',
#  ' she thought',
#  ' he might',
#  ' she could',
#  ' she could',
#  ' she expected',
#  ' she soon',
#  ' he was',
#  ' she wished',
#  ' she had',
#  ' she became',
#  ' She had',
#  ' she had',
#  ' she would',
#  ' she had',
#  ' she had',
#  ' she was',
#  ' he unfolded',
#  ' he must',
#  ' he begged',
#  ' he listened',
#  ' she was',
#  ' he left',
#  ' she persisted',
#  ' she was',
#  ' she trusted',
#  ' she herself',
#  ' she principally',
#  ' she could',
#  ' she could',
#  ' she could',
#  ' he did',
#  ' he pronounced',
#  ' he said',
#  ' he had',
#  ' she said',
#  ' she called',
#  ' she was',
#  ' she was',
#  ' she grew',
#  ' she might',
#  ' he proceeded',
#  ' he had',
#  ' he hoped',
#  ' he added',
#  ' she wished',
#  ' he trusted',
#  ' she was',
#  ' he should',
#  ' She hated',
#  ' she never',
#  ' she was',
#  ' she could',
#  ' she feared',
#  ' she felt',
#  ' she was',
#  ' she did',
#  ' he did',
#  ' she would',
#  ' He was',
#  ' he sometimes',
#  ' she went',
#  ' she was',
#  ' she regarded',
#  ' she concluded',
#  ' she spoke',
#  ' She complained',
#  ' she went',
#  ' he have',
#  ' he left',
#  ' she found',
#  ' She wrote',
#  ' she paid',
#  ' he was',
#  ' she doubted',
#  ' she had',
#  ' she had',
#  ' she could',
#  ' he might',
#  ' he thought',
#  ' she thought',
#  ' he must',
#  ' She could',
#  ' he had',
#  ' she could',
#  ' She can',
#  ' she gives',
#  ' He will',
#  ' He may',
#  ' she soon',
#  ' she is',
#  ' she may',
#  ' he is',
#  ' he is',
#  ' he were',
#  ' she did',
#  ' he saw',
#  ' she had',
#  ' he one',
#  ' He is',
#  ' he had',
#  ' he had',
#  ' He took',
#  ' she had',
#  ' she last',
#  ' she continued',
#  ' she could',
#  ' she might',
#  ' He made',
#  ' she refused',
#  ' she spoke',
#  ' he was',
#  ' he was',
#  ' he offended',
#  ' she may',
#  ' she would',
#  ' he really',
#  ' he is',
#  ' he would',
#  ' he once',
#  ' She will',
#  ' she felt',
#  ' she did',
#  ' she thought',
#  ' she hoped',
#  ' she might',
#  ' she saw',
#  ' she resolved',
#  ' she left',
#  ' she had',
#  ' he belonged',
#  ' she had',
#  ' she was',
#  ' she tried',
#  ' she recollected',
#  ' she thought',
#  ' she thus',
#  ' he is',
#  ' he had',
#  ' he ought',
#  ' He shall',
#  ' he is',
#  ' he becomes',
#  ' he should',
#  ' he is',
#  ' he has',
#  ' she was',
#  ' he took',
#  ' she was',
#  ' she ',
#  ' she rose',
#  ' she foresaw',
#  ' she would',
#  ' she would',
#  ' she would',
#  ...]

# %% [markdown]
# ## Use capture groups to save the pronoun (he/she) as one match and the word as another
#
# The first five should look like
#
# ```
# [('he', 'is'),
#  ('he', 'had'),
#  ('she', 'told'),
#  ('he', 'came'),
#  ('he', 'agreed')]```

# %%
pronouns = re.findall(r"[\n ]+(he*|she*) (\w*)", book, re.IGNORECASE)
pronouns
# Out:
# [('he', 'is'),
#  ('he', 'had'),
#  ('she', 'told'),
#  ('he', 'came'),
#  ('he', 'agreed'),
#  ('he', 'is'),
#  ('he', 'married'),
#  ('he', 'may'),
#  ('he', 'comes'),
#  ('she', 'ought'),
#  ('he', 'comes'),
#  ('he', 'chooses'),
#  ('she', 'is'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'fancied'),
#  ('He', 'had'),
#  ('he', 'should'),
#  ('she', 'had'),
#  ('he', 'suddenly'),
#  ('She', 'has'),
#  ('She', 'is'),
#  ('she', 'will'),
#  ('she', 'will'),
#  ('he', 'continued'),
#  ('he', 'wished'),
#  ('she', 'began'),
#  ('she', 'had'),
#  ('he', 'spoke'),
#  ('he', 'left'),
#  ('he', 'would'),
#  ('he', 'eluded'),
#  ('He', 'was'),
#  ('he', 'meant'),
#  ('He', 'had'),
#  ('he', 'had'),
#  ('he', 'saw'),
#  ('he', 'wore'),
#  ('She', 'could'),
#  ('he', 'could'),
#  ('she', 'began'),
#  ('he', 'might'),
#  ('he', 'ought'),
#  ('he', 'brought'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('He', 'was'),
#  ('he', 'would'),
#  ('She', 'is'),
#  ('he', 'looked'),
#  ('he', 'withdrew'),
#  ('She', 'told'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('He', 'had'),
#  ('he', ''),
#  ('he', 'had'),
#  ('she', 'entered'),
#  ('she', 'looked'),
#  ('he', 'actually'),
#  ('she', 'was'),
#  ('he', 'asked'),
#  ('he', 'asked'),
#  ('he', 'did'),
#  ('he', 'seemed'),
#  ('she', 'was'),
#  ('he', 'inquired'),
#  ('she', 'was'),
#  ('he', 'danced'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('He', 'is'),
#  ('she', 'was'),
#  ('She', 'was'),
#  ('she', 'added'),
#  ('he', 'is'),
#  ('He', 'walked'),
#  ('he', 'walked'),
#  ('she', 'admired'),
#  ('he', 'possibly'),
#  ('He', 'could'),
#  ('he', 'certainly'),
#  ('she', 'was'),
#  ('he', 'was'),
#  ('he', 'might'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('He', 'did'),
#  ('he', 'never'),
#  ('He', 'was'),
#  ('he', 'appeared'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'had'),
#  ('he', 'acknowledged'),
#  ('she', 'smiled'),
#  ('he', 'chose'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'seemed'),
#  ('he', 'danced'),
#  ('he', 'admired'),
#  ('he', '_did_'),
#  ('he', 'liked'),
#  ('he', 'did'),
#  ('he', 'thought'),
#  ('he', 'is'),
#  ('he', 'sat'),
#  ('she', 'asked'),
#  ('he', 'liked'),
#  ('he', 'could'),
#  ('she', 'said'),
#  ('he', 'seemed'),
#  ('he', 'never'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'would'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'has'),
#  ('he', 'had'),
#  ('she', 'should'),
#  ('she', 'continued'),
#  ('she', 'would'),
#  ('he', 'did'),
#  ('she', 'had'),
#  ('she', 'considered'),
#  ('She', 'mentioned'),
#  ('she', 'may'),
#  ('she', 'feels'),
#  ('he', 'may'),
#  ('she', 'does'),
#  ('she', 'does'),
#  ('he', 'must'),
#  ('he', 'does'),
#  ('he', 'must'),
#  ('he', 'must'),
#  ('he', 'sees'),
#  ('she', 'can'),
#  ('she', 'is'),
#  ('she', 'chooses'),
#  ('she', 'is'),
#  ('she', 'cannot'),
#  ('She', 'has'),
#  ('She', 'danced'),
#  ('she', 'saw'),
#  ('she', 'merely'),
#  ('she', 'might'),
#  ('he', 'had'),
#  ('she', 'were'),
#  ('she', 'had'),
#  ('she', 'were'),
#  ('she', 'was'),
#  ('he', 'had'),
#  ('he', 'looked'),
#  ('he', 'made'),
#  ('she', 'hardly'),
#  ('he', 'began'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('she', 'was'),
#  ('he', 'was'),
#  ('He', 'began'),
#  ('she', 'to'),
#  ('he', 'does'),
#  ('he', 'is'),
#  ('He', 'has'),
#  ('she', 'turned'),
#  ('she', 'added'),
#  ('she', 'could'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('he', 'continued'),
#  ('He', 'paused'),
#  ('he', 'was'),
#  ('he', 'would'),
#  ('she', 'instantly'),
#  ('he', 'can'),
#  ('he', 'was'),
#  ('he', 'would'),
#  ('she', 'been'),
#  ('she', 'will'),
#  ('He', 'listened'),
#  ('she', 'chose'),
#  ('She', 'had'),
#  ('he', 'was'),
#  ('she', 'sees'),
#  ('she', 'was'),
#  ('he', 'say'),
#  ('She', 'did'),
#  ('she', 'was'),
#  ('she', 'should'),
#  ('She', 'will'),
#  ('she', 'stays'),
#  ('she', 'was'),
#  ('She', 'declared'),
#  ('he', 'goes'),
#  ('She', 'was'),
#  ('she', 'should'),
#  ('She', 'was'),
#  ('she', 'longed'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'saw'),
#  ('she', 'had'),
#  ('she', 'must'),
#  ('she', 'only'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'believed'),
#  ('she', 'was'),
#  ('She', 'had'),
#  ('he', 'was'),
#  ('he', 'found'),
#  ('she', 'returned'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('She', 'really'),
#  ('she', 'be'),
#  ('she', 'came'),
#  ('she', 'mean'),
#  ('he', 'replied'),
#  ('she', 'is'),
#  ('she', 'were'),
#  ('She', 'was'),
#  ('she', 'had'),
#  ('she', 'should'),
#  ('she', 'found'),
#  ('she', 'declined'),
#  ('she', 'would'),
#  ('she', 'could'),
#  ('She', 'is'),
#  ('He', 'immediately'),
#  ('she', 'could'),
#  ('he', 'replied'),
#  ('she', 'drew'),
#  ('she', 'be'),
#  ('she', 'will'),
#  ('She', 'is'),
#  ('she', 'was'),
#  ('she', 'must'),
#  ('she', 'must'),
#  ('she', 'must'),
#  ('she', 'could'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('he', 'could'),
#  ('she', 'very'),
#  ('she', 'requested'),
#  ('she', 'found'),
#  ('she', 'had'),
#  ('She', 'would'),
#  ('she', 'expected'),
#  ('she', 'remains'),
#  ('she', 'added'),
#  ('she', 'is'),
#  ('she', 'has'),
#  ('she', 'had'),
#  ('he', 'replied'),
#  ('He', 'only'),
#  ('she', 'called'),
#  ('He', 'had'),
#  ('she', 'would'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('she', 'is'),
#  ('she', 'was'),
#  ('he', 'would'),
#  ('he', 'did'),
#  ('he', 'thought'),
#  ('he', 'wrote'),
#  ('She', 'longed'),
#  ('She', 'performed'),
#  ('She', 'had'),
#  ('She', 'was'),
#  ('he', 'did'),
#  ('she', 'is'),
#  ('she', 'added'),
#  ('he', 'does'),
#  ('He', 'made'),
#  ('He', 'was'),
#  ('he', 'does'),
#  ('He', 'studies'),
#  ('He', 'leaves'),
#  ('he', 'did'),
#  ('he', 'would'),
#  ('he', 'has'),
#  ('she', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('he', 'applied'),
#  ('she', 'seated'),
#  ('she', 'turned'),
#  ('She', 'hardly'),
#  ('she', 'could'),
#  ('he', 'should'),
#  ('he', 'disliked'),
#  ('She', 'could'),
#  ('she', 'drew'),
#  ('She', 'liked'),
#  ('She', 'smiled'),
#  ('He', 'repeated'),
#  ('he', 'was'),
#  ('He', 'really'),
#  ('he', 'should'),
#  ('She', 'often'),
#  ('she', 'left'),
#  ('She', 'then'),
#  ('she', 'rambled'),
#  ('she', 'was'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('He', 'addressed'),
#  ('he', 'was'),
#  ('He', 'was'),
#  ('she', 'should'),
#  ('she', 'removed'),
#  ('she', 'might'),
#  ('He', 'then'),
#  ('She', 'had'),
#  ('She', 'assured'),
#  ('she', 'was'),
#  ('She', 'could'),
#  ('he', 'merely'),
#  ('she', 'had'),
#  ('she', 'gave'),
#  ('She', 'then'),
#  ('she', 'turned'),
#  ('he', 'chooses'),
#  ('she', 'replied'),
#  ('she', 'got'),
#  ('she', 'walked'),
#  ('she', 'resolved'),
#  ('He', 'was'),
#  ('He', 'was'),
#  ('he', 'declined'),
#  ('he', 'could'),
#  ('he', 'mean'),
#  ('She', 'was'),
#  ('she', 'could'),
#  ('he', 'means'),
#  ('she', 'allowed'),
#  ('he', 'may'),
#  ('He', 'owns'),
#  ('he', 'replied'),
#  ('she', 'had'),
#  ('He', 'began'),
#  ('she', 'was'),
#  ('she', 'could'),
#  ('she', 'much'),
#  ('she', 'urged'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('she', 'felt'),
#  ('She', 'attracted'),
#  ('he', 'liked'),
#  ('He', 'wisely'),
#  ('he', 'scarcely'),
#  ('he', 'adhered'),
#  ('she', 'even'),
#  ('he', 'had'),
#  ('she', 'often'),
#  ('he', 'had'),
#  ('he', 'thus'),
#  ('he', 'pleases'),
#  ('she', 'continued'),
#  ('he', 'not'),
#  ('he', 'does'),
#  ('he', 'folded'),
#  ('he', 'says'),
#  ('he', 'is'),
#  ('he', 'can'),
#  ('he', 'thinks'),
#  ('he', 'mean'),
#  ('he', 'would'),
#  ('he', 'could'),
#  ('he', 'be'),
#  ('she', 'was'),
#  ('He', 'was'),
#  ('He', 'had'),
#  ('he', 'complimented'),
#  ('he', 'had'),
#  ('he', 'did'),
#  ('He', 'was'),
#  ('he', 'begged'),
#  ('he', 'was'),
#  ('He', 'begged'),
#  ('she', 'declared'),
#  ('he', 'continued'),
#  ('he', 'thought'),
#  ('he', 'expected'),
#  ('he', 'seemed'),
#  ('he', 'protested'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('he', 'knew'),
#  ('he', 'had'),
#  ('She', 'had'),
#  ('she', 'would'),
#  ('she', 'made'),
#  ('She', 'had'),
#  ('he', 'could'),
#  ('he', 'chose'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('she', 'is'),
#  ('she', 'live'),
#  ('she', 'was'),
#  ('she', 'any'),
#  ('she', 'is'),
#  ('she', 'handsome'),
#  ('She', 'is'),
#  ('she', 'could'),
#  ('she', 'is'),
#  ('she', 'been'),
#  ('he', 'had'),
#  ('he', 'listened'),
#  ('he', 'started'),
#  ('he', 'never'),
#  ('he', 'chose'),
#  ('he', 'opened'),
#  ('he', 'had'),
#  ('she', 'interrupted'),
#  ('he', 'does'),
#  ('he', 'offered'),
#  ('he', 'acted'),
#  ('he', 'would'),
#  ('he', 'bore'),
#  ('he', 'belonged'),
#  ('he', 'had'),
#  ('he', 'felt'),
#  ('he', 'intended'),
#  ('he', 'had'),
#  ('he', 'meant'),
#  ('he', 'found'),
#  ('he', 'thought'),
#  ('she', 'was'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('she', 'did'),
#  ('she', 'must'),
#  ('she', 'might'),
#  ('she', 'could'),
#  ('he', 'would'),
#  ('he', 'had'),
#  ('he', 'told'),
#  ('he', 'was'),
#  ('he', 'bowed'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('He', 'was'),
#  ('he', 'said'),
#  ('she', 'was'),
#  ('she', 'should'),
#  ('she', 'had'),
#  ('She', 'received'),
#  ('he', 'returned'),
#  ('he', 'could'),
#  ('she', 'could'),
#  ('he', 'was'),
#  ('She', 'had'),
#  ('she', 'said'),
#  ('he', 'walked'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('He', 'protested'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('he', 'supposed'),
#  ('he', 'had'),
#  ('he', 'was'),
#  ('he', 'declared'),
#  ('he', 'might'),
#  ('she', 'had'),
#  ('she', 'felt'),
#  ('he', 'was'),
#  ('he', 'found'),
#  ('she', 'heard'),
#  ('she', 'could'),
#  ('she', 'had'),
#  ('he', 'finally'),
#  ('he', 'immediately'),
#  ('he', 'certainly'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('he', 'received'),
#  ('she', 'was'),
#  ('she', 'soon'),
#  ('she', 'was'),
#  ('she', 'chiefly'),
#  ('she', 'could'),
#  ('She', 'dared'),
#  ('He', 'inquired'),
#  ('He', 'is'),
#  ('he', 'or'),
#  ('he', 'chooses'),
#  ('he', 'is'),
#  ('he', 'wishes'),
#  ('he', 'must'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'added'),
#  ('He', 'was'),
#  ('He', 'meant'),
#  ('he', 'had'),
#  ('he', 'hates'),
#  ('He', 'deserves'),
#  ('he', 'will'),
#  ('he', 'expressed'),
#  ('He', 'had'),
#  ('she', 'continued'),
#  ('She', 'could'),
#  ('she', 'contented'),
#  ('he', 'gave'),
#  ('He', 'was'),
#  ('he', 'felt'),
#  ('he', 'should'),
#  ('he', 'is'),
#  ('He', 'has'),
#  ('He', 'shook'),
#  ('she', 'is'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('She', 'is'),
#  ('He', 'cannot'),
#  ('he', 'chooses'),
#  ('He', 'does'),
#  ('He', 'can'),
#  ('he', 'thinks'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'assured'),
#  ('he', 'considered'),
#  ('she', 'would'),
#  ('he', 'asked'),
#  ('she', 'replied'),
#  ('he', 'certainly'),
#  ('she', 'is'),
#  ('she', 'and'),
#  ('she', 'thought'),
#  ('he', 'were'),
#  ('he', 'has'),
#  ('she', 'is'),
#  ('She', 'has'),
#  ('she', 'derives'),
#  ('he', 'had'),
#  ('he', 'said'),
#  ('he', 'did'),
#  ('She', 'could'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('he', 'did'),
#  ('he', 'crowded'),
#  ('he', 'could'),
#  ('she', 'knew'),
#  ('he', 'gave'),
#  ('he', 'had'),
#  ('she', 'had'),
#  ('he', 'was'),
#  ('she', 'had'),
#  ('she', 'did'),
#  ('she', 'could'),
#  ('he', 'intended'),
#  ('he', 'did'),
#  ('he', 'would'),
#  ('she', 'was'),
#  ('he', 'entertained'),
#  ('She', 'had'),
#  ('she', 'could'),
#  ('She', 'was'),
#  ('she', 'was'),
#  ('she', 'observed'),
#  ('he', 'did'),
#  ('She', 'had'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('he', 'directly'),
#  ('She', 'was'),
#  ('she', 'could'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('She', 'danced'),
#  ('he', 'was'),
#  ('she', 'returned'),
#  ('she', 'found'),
#  ('she', 'did'),
#  ('she', 'accepted'),
#  ('He', 'walked'),
#  ('she', 'was'),
#  ('she', 'was'),
#  ('she', 'began'),
#  ('she', 'made'),
#  ('He', 'replied'),
#  ('she', 'addressed'),
#  ('He', 'smiled'),
#  ('she', 'wished'),
#  ('He', 'made'),
#  ('he', 'asked'),
#  ('she', 'and'),
#  ('She', 'answered'),
#  ('he', 'said'),
#  ('he', 'may'),
#  ('he', 'is'),
#  ('he', 'stopped'),
#  ('he', 'turned'),
#  ('she', 'replied'),
#  ('she', 'said'),
#  ('She', 'shook'),
#  ('he', 'gravely'),
#  ('he', 'coldly'),
#  ('She', 'said'),
#  ('he', 'was'),
#  ('he', 'has'),
#  ('he', 'cannot'),
#  ('he', 'could'),
#  ('he', 'was'),
#  ('he', 'had'),
#  ('he', 'could'),
#  ('he', 'informed'),
#  ('She', 'then'),
#  ('she', 'was'),
#  ('he', 'will'),
#  ('he', 'has'),
#  ('he', 'has'),
#  ('he', 'never'),
#  ('he', 'has'),
#  ('he', 'say'),
#  ('he', 'has'),
#  ('he', 'believes'),
#  ('he', 'is'),
#  ('She', 'then'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('he', 'will'),
#  ('she', 'ceased'),
#  ('he', 'left'),
#  ('she', 'eagerly'),
#  ('she', 'could'),
#  ('she', 'felt'),
#  ('he', 'only'),
#  ('He', 'answered'),
#  ('he', 'was'),
#  ('she', 'could'),
#  ('she', 'turned'),
#  ('She', 'saw'),
#  ('she', 'felt'),
#  ('she', 'plainly'),
#  ('she', 'determined'),
#  ('she', 'might'),
#  ('she', 'considered'),
#  ('she', 'vexed'),
#  ('she', 'could'),
#  ('she', 'might'),
#  ('she', 'liked'),
#  ('She', 'concluded'),
#  ('she', 'could'),
#  ('he', 'may'),
#  ('she', 'could'),
#  ('She', 'could'),
#  ('she', 'dreaded'),
#  ('he', 'was'),
#  ('she', 'was'),
#  ('she', 'saw'),
#  ('she', 'had'),
#  ('she', 'endeavour'),
#  ('she', 'began'),
#  ('she', 'watched'),
#  ('she', 'might'),
#  ('She', 'looked'),
#  ('she', 'bore'),
#  ('She', 'looked'),
#  ('She', 'looked'),
#  ('He', 'took'),
#  ('he', 'must'),
#  ('He', 'must'),
#  ('he', 'cannot'),
#  ('he', 'should'),
#  ('he', 'owes'),
#  ('he', 'concluded'),
#  ('he', 'was'),
#  ('she', 'think'),
#  ('he', 'must'),
#  ('she', 'could'),
#  ('She', 'was'),
#  ('he', 'could'),
#  ('she', 'entreat'),
#  ('He', 'assured'),
#  ('he', 'was'),
#  ('he', 'should'),
#  ('She', 'owed'),
#  ('She', 'was'),
#  ('he', 'never'),
#  ('She', 'felt'),
#  ('he', 'would'),
#  ('he', 'readily'),
#  ('he', 'was'),
#  ('she', 'should'),
#  ('she', 'thought'),
#  ('he', 'set'),
#  ('he', 'supposed'),
#  ('he', 'addressed'),
#  ('she', 'can'),
#  ('she', 'was'),
#  ('He', 'can'),
#  ('she', 'added'),
#  ('she', 'sat'),
#  ('she', 'could'),
#  ('he', 'allowed'),
#  ('he', 'continued'),
#  ('she', 'condescended'),
#  ('she', 'said'),
#  ('she', 'cried'),
#  ('he', 'first'),
#  ('she', 'would'),
#  ('she', 'thus'),
#  ('she', 'would'),
#  ('he', 'persisted'),
#  ('she', 'entered'),
#  ('he', 'trusted'),
#  ('he', 'had'),
#  ('she', 'would'),
#  ('she', 'dared'),
#  ('she', 'added'),
#  ('She', 'is'),
#  ('she', 'is'),
#  ('she', 'would'),
#  ('she', 'actually'),
#  ('she', 'could'),
#  ('she', 'is'),
#  ('She', 'would'),
#  ('she', 'entered'),
#  ('she', 'vows'),
#  ('she', 'will'),
#  ('he', 'will'),
#  ('she', 'entered'),
#  ('she', 'had'),
#  ('she', 'will'),
#  ('he', 'will'),
#  ('She', 'shall'),
#  ('she', 'appeared'),
#  ('she', 'wished'),
#  ('She', 'talked'),
#  ('She', 'endeavoured'),
#  ('He', 'thought'),
#  ('he', 'suffered'),
#  ('She', 'was'),
#  ('she', 'will'),
#  ('she', 'likewise'),
#  ('she', 'added'),
#  ('she', 'comes'),
#  ('she', 'can'),
#  ('She', 'talked'),
#  ('she', 'said'),
#  ('she', 'could'),
#  ('he', 'presently'),
#  ('He', 'scarcely'),
#  ('he', 'had'),
#  ('He', 'was'),
#  ('he', 'meant'),
#  ('He', 'joined'),
#  ('he', 'voluntarily'),
#  ('She', 'highly'),
#  ('he', 'particularly'),
#  ('she', 'felt'),
#  ('she', 'read'),
#  ('he', 'and'),
#  ('he', 'companion'),
#  ('she', 'says'),
#  ('She', 'then'),
#  ('she', 'saw'),
#  ('she', 'was'),
#  ('she', 'is'),
#  ('he', 'imagined'),
#  ('he', 'will'),
#  ('he', 'may'),
#  ('he', 'comes'),
#  ('he', 'should'),
#  ('He', 'is'),
#  ('she', 'inspires'),
#  ('he', 'will'),
#  ('she', 'finished'),
#  ('she', 'is'),
#  ('she', 'suspects'),
#  ('she', 'means'),
#  ('She', 'follows'),
#  ('he', 'does'),
#  ('She', 'is'),
#  ('she', 'have'),
#  ('she', 'would'),
#  ('she', 'is'),
#  ('she', 'may'),
#  ('he', 'is'),
#  ('he', 'took'),
#  ('he', 'is'),
#  ('she', 'is'),
#  ('he', 'returns'),
#  ('she', 'could'),
#  ('She', 'represented'),
#  ('she', 'felt'),
#  ('she', 'was'),
#  ('she', 'bewailed'),
#  ('she', 'had'),
#  ('he', 'had'),
#  ('she', 'would'),
#  ('she', 'would'),
#  ('he', 'had'),
#  ('she', 'did'),
#  ('He', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'walked'),
#  ('she', 'dared'),
#  ('he', 'earnestly'),
#  ('he', 'was'),
#  ('he', 'and'),
#  ('She', 'had'),
#  ('he', 'would'),
#  ('she', 'had'),
#  ('she', 'felt'),
#  ('she', 'valued'),
#  ('She', 'resolved'),
#  ('he', 'returned'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'replied'),
#  ('he', 'meditated'),
#  ('he', 'thought'),
#  ('She', 'rated'),
#  ('she', 'thought'),
#  ('he', 'might'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'expected'),
#  ('she', 'soon'),
#  ('he', 'was'),
#  ('she', 'wished'),
#  ('she', 'had'),
#  ('she', 'became'),
#  ('She', 'had'),
#  ('she', 'had'),
#  ('she', 'would'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('he', 'unfolded'),
#  ('he', 'must'),
#  ('he', 'begged'),
#  ('he', 'listened'),
#  ('she', 'was'),
#  ('he', 'left'),
#  ('she', 'persisted'),
#  ('she', 'was'),
#  ('she', 'trusted'),
#  ('she', 'herself'),
#  ('she', 'principally'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('she', 'could'),
#  ('he', 'did'),
#  ('he', 'pronounced'),
#  ('he', 'said'),
#  ('he', 'had'),
#  ('she', 'said'),
#  ('she', 'called'),
#  ('she', 'was'),
#  ('she', 'was'),
#  ('she', 'grew'),
#  ('she', 'might'),
#  ('he', 'proceeded'),
#  ('he', 'had'),
#  ('he', 'hoped'),
#  ('he', 'added'),
#  ('she', 'wished'),
#  ('he', 'trusted'),
#  ('she', 'was'),
#  ('he', 'should'),
#  ('She', 'hated'),
#  ('she', 'never'),
#  ('she', 'was'),
#  ('she', 'could'),
#  ('she', 'feared'),
#  ('she', 'felt'),
#  ('she', 'was'),
#  ('she', 'did'),
#  ('he', 'did'),
#  ('she', 'would'),
#  ('He', 'was'),
#  ('he', 'sometimes'),
#  ('she', 'went'),
#  ('she', 'was'),
#  ('she', 'regarded'),
#  ('she', 'concluded'),
#  ('she', 'spoke'),
#  ('She', 'complained'),
#  ('she', 'went'),
#  ('he', 'have'),
#  ('he', 'left'),
#  ('she', 'found'),
#  ('She', 'wrote'),
#  ('she', 'paid'),
#  ('he', 'was'),
#  ('she', 'doubted'),
#  ('she', 'had'),
#  ('she', 'had'),
#  ('she', 'could'),
#  ('he', 'might'),
#  ('he', 'thought'),
#  ('she', 'thought'),
#  ('he', 'must'),
#  ('She', 'could'),
#  ('he', 'had'),
#  ('she', 'could'),
#  ('She', 'can'),
#  ('she', 'gives'),
#  ('He', 'will'),
#  ('He', 'may'),
#  ('she', 'soon'),
#  ('she', 'is'),
#  ('she', 'may'),
#  ('he', 'is'),
#  ('he', 'is'),
#  ('he', 'were'),
#  ('she', 'did'),
#  ('he', 'saw'),
#  ('she', 'had'),
#  ('he', 'one'),
#  ('He', 'is'),
#  ('he', 'had'),
#  ('he', 'had'),
#  ('He', 'took'),
#  ('she', 'had'),
#  ('she', 'last'),
#  ('she', 'continued'),
#  ('she', 'could'),
#  ('she', 'might'),
#  ('He', 'made'),
#  ('she', 'refused'),
#  ('she', 'spoke'),
#  ('he', 'was'),
#  ('he', 'was'),
#  ('he', 'offended'),
#  ('she', 'may'),
#  ('she', 'would'),
#  ('he', 'really'),
#  ('he', 'is'),
#  ('he', 'would'),
#  ('he', 'once'),
#  ('She', 'will'),
#  ('she', 'felt'),
#  ('she', 'did'),
#  ('she', 'thought'),
#  ('she', 'hoped'),
#  ('she', 'might'),
#  ('she', 'saw'),
#  ('she', 'resolved'),
#  ('she', 'left'),
#  ('she', 'had'),
#  ('he', 'belonged'),
#  ('she', 'had'),
#  ('she', 'was'),
#  ('she', 'tried'),
#  ('she', 'recollected'),
#  ('she', 'thought'),
#  ('she', 'thus'),
#  ('he', 'is'),
#  ('he', 'had'),
#  ('he', 'ought'),
#  ('He', 'shall'),
#  ('he', 'is'),
#  ('he', 'becomes'),
#  ('he', 'should'),
#  ('he', 'is'),
#  ('he', 'has'),
#  ('she', 'was'),
#  ('he', 'took'),
#  ('she', 'was'),
#  ('she', ''),
#  ('she', 'rose'),
#  ('she', 'foresaw'),
#  ('she', 'would'),
#  ('she', 'would'),
#  ('she', 'would'),
#  ...]

# %% [markdown]
# ## Save those matches into a dataframe
#
# You can give the column names with `columns=['pronoun', 'verb']`

# %%
df = pd.DataFrame(pronouns, columns=['pronoun', 'verb'])
df.head()
# Out:
#   pronoun    verb
# 0      he      is
# 1      he     had
# 2     she    told
# 3      he    came
# 4      he  agreed

# %% [markdown]
# ## How many times is each pronoun used?

# %%
df.pronoun.value_counts()
# Out:
# she    1316
# he     1048
# She     306
# He      212
# Name: pronoun, dtype: int64

# %% [markdown]
# ## Oh, wait, clean that up.
#
# Make it only 'he' and 'she' lowercase.
#
# It should be about 1600 'she' and 1300 'he'

# %%
df['pronoun']= df.pronoun.str.lower()
df.pronoun.value_counts()
# Out:
# she    1622
# he     1260
# Name: pronoun, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs?

# %%
df.verb.value_counts().head(20)
# Out:
# was          371
# had          369
# could        170
# is           116
# would         92
# has           65
# did           64
# will          49
# might         46
# should        41
# felt          37
# must          36
# said          33
# added         31
# thought       31
# saw           31
# then          26
# replied       22
# continued     21
# looked        20
# Name: verb, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs for 'he', and the top 20 most common for 'she'
#
# **Tip:** Don't use groupby, just filter. If you want to know how, though, you can also look at "value counts for different categories" on [this page](http://jonathansoma.com/lede/foundations-2017/classes/more-pandas/class-notes/)

# %% [markdown]
# ## Who cries more, men or women? Give me a percentage answer.
#
# **Tip:** It's `cried`, because of, you know, how books are written

# %% [markdown]
# ## How much more common is 'he' than 'she' in J.R.R. Tolkein's Fellowship of the Ring? How does that compare to Pride and Prejudice?
#
# The book is in the same directory.

# %%
lotr = open("data/Lord of the Rings - 01 - The Fellowship of the Ring - J. R. R. Tolkien - 1955.txt", encoding = 'utf8').read()

# %%
lotr[:500]
# Out:
# 'THE FELLOWSHIP OF THE RING\n\n\n\n\nBEING THE FIRST PART OF\n\nTHE LORD OF THE RINGS\n\nBY\n\nJ.R.R. TOLKIEN\n\n\n\n\n\nThree Rings for the Elven-kings under the sky,\n\nSeven for the Dwarf-lords in their halls of stone,\n\nNine for Mortal Men doomed to die,\n\nOne for the Dark Lord on his dark throne\n\nIn the Land of Mordor where the Shadows lie.\n\nOne Ring to rule them all, One Ring to find them,\n\nOne Ring to bring them all and in the darkness bind them\n\nIn the Land of Mordor where the Shadows lie.\n\n\n\n\n\nCONTENTS\n\n\nCOV'

# %%
df = pd.DataFrame(re.findall(r"[\n ]+he\b|[\n ]+she\b", lotr, re.IGNORECASE), columns=["pronoun"])
df['pronoun']= df.pronoun.str.lower()
df['pronoun']= df.pronoun.str.strip()

df.pronoun.value_counts("normalize")*100
# Out:
# he     95.047619
# she     4.952381
# Name: pronoun, dtype: float64
