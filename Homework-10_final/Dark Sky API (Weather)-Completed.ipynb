# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
# 15074402c474e3dab67f7377e1f95519

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
# https://api.darksky.net/forecast/[key]/[latitude],[longitude]

# Charlottesville, VA
# 38.0293° N, 78.4767° W

# %%
url = "https://api.darksky.net/forecast/15074402c474e3dab67f7377e1f95519/38.0293,-78.4767"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# JSON - JavaScript Object Notation => "it works like a dictionary"
data = response.json()

# %%
data
# Out:
# {'currently': {'apparentTemperature': 85.8,
#   'cloudCover': 0.23,
#   'dewPoint': 61.22,
#   'humidity': 0.44,
#   'icon': 'clear-day',
#   'nearestStormBearing': 145,
#   'nearestStormDistance': 62,
#   'ozone': 344.1,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1010.45,
#   'summary': 'Clear',
#   'temperature': 85.55,
#   'time': 1496611765,
#   'visibility': 10,
#   'windBearing': 177,
#   'windSpeed': 7.52},
#  'daily': {'data': [{'apparentTemperatureMax': 86.32,
#     'apparentTemperatureMaxTime': 1496613600,
#     'apparentTemperatureMin': 55.5,
#     'apparentTemperatureMinTime': 1496566800,
#     'cloudCover': 0.15,
#     'dewPoint': 58.01,
#     'humidity': 0.62,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.35,
#     'ozone': 345.66,
#     'precipIntensity': 0.0005,
#     'precipIntensityMax': 0.0049,
#     'precipIntensityMaxTime': 1496631600,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'pressure': 1013.85,
#     'summary': 'Mostly cloudy starting in the evening.',
#     'sunriseTime': 1496570001,
#     'sunsetTime': 1496622847,
#     'temperatureMax': 86.25,
#     'temperatureMaxTime': 1496606400,
#     'temperatureMin': 55.5,
#     'temperatureMinTime': 1496566800,
#     'time': 1496548800,
#     'visibility': 9.97,
#     'windBearing': 190,
#     'windSpeed': 3.57},
#    {'apparentTemperatureMax': 75.19,
#     'apparentTemperatureMaxTime': 1496685600,
#     'apparentTemperatureMin': 66.65,
#     'apparentTemperatureMinTime': 1496718000,
#     'cloudCover': 0.88,
#     'dewPoint': 66.15,
#     'humidity': 0.86,
#     'icon': 'rain',
#     'moonPhase': 0.38,
#     'ozone': 333.78,
#     'precipIntensity': 0.0498,
#     'precipIntensityMax': 0.1471,
#     'precipIntensityMaxTime': 1496696400,
#     'precipProbability': 0.83,
#     'precipType': 'rain',
#     'pressure': 1007.9,
#     'summary': 'Rain until evening.',
#     'sunriseTime': 1496656385,
#     'sunsetTime': 1496709283,
#     'temperatureMax': 75.19,
#     'temperatureMaxTime': 1496685600,
#     'temperatureMin': 66.65,
#     'temperatureMinTime': 1496718000,
#     'time': 1496635200,
#     'visibility': 7.36,
#     'windBearing': 200,
#     'windSpeed': 3.57},
#    {'apparentTemperatureMax': 80.26,
#     'apparentTemperatureMaxTime': 1496779200,
#     'apparentTemperatureMin': 61.68,
#     'apparentTemperatureMinTime': 1496804400,
#     'cloudCover': 0.31,
#     'dewPoint': 59.15,
#     'humidity': 0.71,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.41,
#     'ozone': 348.02,
#     'precipIntensity': 0.0019,
#     'precipIntensityMax': 0.0043,
#     'precipIntensityMaxTime': 1496728800,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'pressure': 1006.14,
#     'summary': 'Partly cloudy in the morning.',
#     'sunriseTime': 1496742771,
#     'sunsetTime': 1496795718,
#     'temperatureMax': 80.01,
#     'temperatureMaxTime': 1496779200,
#     'temperatureMin': 61.68,
#     'temperatureMinTime': 1496804400,
#     'time': 1496721600,
#     'visibility': 10,
#     'windBearing': 296,
#     'windSpeed': 4.95},
#    {'apparentTemperatureMax': 73.3,
#     'apparentTemperatureMaxTime': 1496862000,
#     'apparentTemperatureMin': 55.82,
#     'apparentTemperatureMinTime': 1496826000,
#     'cloudCover': 0.55,
#     'dewPoint': 56.89,
#     'humidity': 0.78,
#     'icon': 'rain',
#     'moonPhase': 0.44,
#     'ozone': 359.73,
#     'precipIntensity': 0.0078,
#     'precipIntensityMax': 0.025,
#     'precipIntensityMaxTime': 1496883600,
#     'precipProbability': 0.64,
#     'precipType': 'rain',
#     'pressure': 1009.64,
#     'summary': 'Light rain starting in the afternoon.',
#     'sunriseTime': 1496829158,
#     'sunsetTime': 1496882152,
#     'temperatureMax': 73.3,
#     'temperatureMaxTime': 1496862000,
#     'temperatureMin': 55.82,
#     'temperatureMinTime': 1496826000,
#     'time': 1496808000,
#     'visibility': 10,
#     'windBearing': 9,
#     'windSpeed': 4.24},
#    {'apparentTemperatureMax': 67.86,
#     'apparentTemperatureMaxTime': 1496948400,
#     'apparentTemperatureMin': 54.67,
#     'apparentTemperatureMinTime': 1496930400,
#     'cloudCover': 0.75,
#     'dewPoint': 56.64,
#     'humidity': 0.88,
#     'icon': 'rain',
#     'moonPhase': 0.47,
#     'ozone': 374.25,
#     'precipIntensity': 0.0066,
#     'precipIntensityMax': 0.0158,
#     'precipIntensityMaxTime': 1496894400,
#     'precipProbability': 0.57,
#     'precipType': 'rain',
#     'pressure': 1011.06,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'sunriseTime': 1496915548,
#     'sunsetTime': 1496968584,
#     'temperatureMax': 67.86,
#     'temperatureMaxTime': 1496948400,
#     'temperatureMin': 54.67,
#     'temperatureMinTime': 1496930400,
#     'time': 1496894400,
#     'windBearing': 35,
#     'windSpeed': 3.33},
#    {'apparentTemperatureMax': 79.33,
#     'apparentTemperatureMaxTime': 1497042000,
#     'apparentTemperatureMin': 53.73,
#     'apparentTemperatureMinTime': 1496995200,
#     'cloudCover': 0.16,
#     'dewPoint': 56.69,
#     'humidity': 0.74,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.51,
#     'ozone': 352.4,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1012.08,
#     'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#     'sunriseTime': 1497001939,
#     'sunsetTime': 1497055015,
#     'temperatureMax': 79.33,
#     'temperatureMaxTime': 1497042000,
#     'temperatureMin': 53.73,
#     'temperatureMinTime': 1496995200,
#     'time': 1496980800,
#     'windBearing': 227,
#     'windSpeed': 2.2},
#    {'apparentTemperatureMax': 83.01,
#     'apparentTemperatureMaxTime': 1497128400,
#     'apparentTemperatureMin': 62.11,
#     'apparentTemperatureMinTime': 1497085200,
#     'cloudCover': 0.09,
#     'dewPoint': 60.36,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.54,
#     'ozone': 355.2,
#     'precipIntensity': 0.0009,
#     'precipIntensityMax': 0.0019,
#     'precipIntensityMaxTime': 1497146400,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'pressure': 1013.71,
#     'summary': 'Partly cloudy in the evening.',
#     'sunriseTime': 1497088332,
#     'sunsetTime': 1497141445,
#     'temperatureMax': 83.21,
#     'temperatureMaxTime': 1497128400,
#     'temperatureMin': 62.11,
#     'temperatureMinTime': 1497085200,
#     'time': 1497067200,
#     'windBearing': 252,
#     'windSpeed': 3.54},
#    {'apparentTemperatureMax': 85.8,
#     'apparentTemperatureMaxTime': 1497211200,
#     'apparentTemperatureMin': 63.44,
#     'apparentTemperatureMinTime': 1497171600,
#     'cloudCover': 0,
#     'dewPoint': 61.45,
#     'humidity': 0.66,
#     'icon': 'clear-day',
#     'moonPhase': 0.56,
#     'ozone': 342.17,
#     'precipIntensity': 0.0011,
#     'precipIntensityMax': 0.0018,
#     'precipIntensityMaxTime': 1497153600,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'pressure': 1016.82,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1497174726,
#     'sunsetTime': 1497227874,
#     'temperatureMax': 86.89,
#     'temperatureMaxTime': 1497211200,
#     'temperatureMin': 63.44,
#     'temperatureMinTime': 1497171600,
#     'time': 1497153600,
#     'windBearing': 246,
#     'windSpeed': 0.87}],
#   'icon': 'rain',
#   'summary': 'Light rain tomorrow through Thursday, with temperatures bottoming out at 68°F on Thursday.'},
#  'flags': {'isd-stations': ['722167-03718',
#    '722167-99999',
#    '722692-99999',
#    '723098-93798',
#    '723098-99999',
#    '723114-03715',
#    '723114-99999',
#    '724016-93736',
#    '724017-03707',
#    '724017-99999',
#    '724033-99999',
#    '724105-93760',
#    '724105-99999',
#    '999999-03759',
#    '999999-13732',
#    '999999-93708'],
#   'lamp-stations': ['KCHO', 'KLKU', 'KOMH', 'KSHD'],
#   'madis-stations': ['C6413',
#    'C8161',
#    'C8477',
#    'C9335',
#    'C9801',
#    'CHAV2',
#    'CROV2',
#    'D7692',
#    'D9115',
#    'E3764',
#    'E4342',
#    'E5086',
#    'E6602',
#    'E6603',
#    'KCHO',
#    'KGVE'],
#   'sources': ['lamp',
#    'gfs',
#    'cmc',
#    'nam',
#    'rap',
#    'rtma',
#    'sref',
#    'fnmoc',
#    'isd',
#    'madis',
#    'nearest-precip',
#    'nwspa',
#    'darksky'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 85.46,
#     'cloudCover': 0.14,
#     'dewPoint': 61.12,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'ozone': 344.47,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.65,
#     'summary': 'Clear',
#     'temperature': 85.21,
#     'time': 1496610000,
#     'visibility': 10,
#     'windBearing': 181,
#     'windSpeed': 7.75},
#    {'apparentTemperature': 86.32,
#     'cloudCover': 0.33,
#     'dewPoint': 61.44,
#     'humidity': 0.44,
#     'icon': 'partly-cloudy-day',
#     'ozone': 343.72,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.26,
#     'summary': 'Partly Cloudy',
#     'temperature': 86.02,
#     'time': 1496613600,
#     'visibility': 10,
#     'windBearing': 173,
#     'windSpeed': 7.32},
#    {'apparentTemperature': 84.32,
#     'cloudCover': 0.4,
#     'dewPoint': 61.11,
#     'humidity': 0.46,
#     'icon': 'partly-cloudy-day',
#     'ozone': 342.92,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.02,
#     'summary': 'Partly Cloudy',
#     'temperature': 83.94,
#     'time': 1496617200,
#     'visibility': 10,
#     'windBearing': 174,
#     'windSpeed': 6.26},
#    {'apparentTemperature': 81.71,
#     'cloudCover': 0.45,
#     'dewPoint': 61.85,
#     'humidity': 0.53,
#     'icon': 'partly-cloudy-day',
#     'ozone': 342.04,
#     'precipIntensity': 0.0009,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1009.95,
#     'summary': 'Partly Cloudy',
#     'temperature': 80.63,
#     'time': 1496620800,
#     'visibility': 10,
#     'windBearing': 174,
#     'windSpeed': 4.97},
#    {'apparentTemperature': 78.04,
#     'cloudCover': 0.47,
#     'dewPoint': 62.98,
#     'humidity': 0.6,
#     'icon': 'partly-cloudy-night',
#     'ozone': 341.12,
#     'precipIntensity': 0.0023,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'pressure': 1010.08,
#     'summary': 'Partly Cloudy',
#     'temperature': 78.04,
#     'time': 1496624400,
#     'visibility': 9.98,
#     'windBearing': 174,
#     'windSpeed': 5.09},
#    {'apparentTemperature': 75.7,
#     'cloudCover': 0.66,
#     'dewPoint': 64.27,
#     'humidity': 0.68,
#     'icon': 'partly-cloudy-night',
#     'ozone': 340.14,
#     'precipIntensity': 0.0041,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'pressure': 1010.37,
#     'summary': 'Mostly Cloudy',
#     'temperature': 75.7,
#     'time': 1496628000,
#     'visibility': 9.92,
#     'windBearing': 177,
#     'windSpeed': 6.07},
#    {'apparentTemperature': 72.76,
#     'cloudCover': 0.67,
#     'dewPoint': 64.63,
#     'humidity': 0.76,
#     'icon': 'partly-cloudy-night',
#     'ozone': 339.05,
#     'precipIntensity': 0.0049,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'pressure': 1010.54,
#     'summary': 'Mostly Cloudy',
#     'temperature': 72.76,
#     'time': 1496631600,
#     'visibility': 9.84,
#     'windBearing': 182,
#     'windSpeed': 6.2},
#    {'apparentTemperature': 71.53,
#     'cloudCover': 0.69,
#     'dewPoint': 64.73,
#     'humidity': 0.79,
#     'icon': 'partly-cloudy-night',
#     'ozone': 337.71,
#     'precipIntensity': 0.0036,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'pressure': 1010.5,
#     'summary': 'Mostly Cloudy',
#     'temperature': 71.53,
#     'time': 1496635200,
#     'visibility': 9.89,
#     'windBearing': 187,
#     'windSpeed': 6.48},
#    {'apparentTemperature': 70.16,
#     'cloudCover': 0.85,
#     'dewPoint': 64.65,
#     'humidity': 0.83,
#     'icon': 'partly-cloudy-night',
#     'ozone': 336.26,
#     'precipIntensity': 0.0013,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1010.34,
#     'summary': 'Mostly Cloudy',
#     'temperature': 70.16,
#     'time': 1496638800,
#     'visibility': 9.97,
#     'windBearing': 192,
#     'windSpeed': 6.61},
#    {'apparentTemperature': 69.27,
#     'cloudCover': 0.88,
#     'dewPoint': 64.53,
#     'humidity': 0.85,
#     'icon': 'partly-cloudy-night',
#     'ozone': 335.16,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.14,
#     'summary': 'Mostly Cloudy',
#     'temperature': 69.27,
#     'time': 1496642400,
#     'visibility': 9.68,
#     'windBearing': 196,
#     'windSpeed': 6.4},
#    {'apparentTemperature': 69,
#     'cloudCover': 0.92,
#     'dewPoint': 64.51,
#     'humidity': 0.86,
#     'icon': 'partly-cloudy-night',
#     'ozone': 334.75,
#     'precipIntensity': 0.0008,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1009.89,
#     'summary': 'Mostly Cloudy',
#     'temperature': 69,
#     'time': 1496646000,
#     'visibility': 8.87,
#     'windBearing': 199,
#     'windSpeed': 6.47},
#    {'apparentTemperature': 68.2,
#     'cloudCover': 0.96,
#     'dewPoint': 64.2,
#     'humidity': 0.87,
#     'icon': 'cloudy',
#     'ozone': 334.68,
#     'precipIntensity': 0.0024,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'pressure': 1009.58,
#     'summary': 'Overcast',
#     'temperature': 68.2,
#     'time': 1496649600,
#     'visibility': 8.01,
#     'windBearing': 200,
#     'windSpeed': 6.49},
#    {'apparentTemperature': 68.22,
#     'cloudCover': 0.99,
#     'dewPoint': 64.65,
#     'humidity': 0.88,
#     'icon': 'rain',
#     'ozone': 334.28,
#     'precipIntensity': 0.0054,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'pressure': 1009.3,
#     'summary': 'Drizzle',
#     'temperature': 68.22,
#     'time': 1496653200,
#     'visibility': 7.63,
#     'windBearing': 201,
#     'windSpeed': 6.46},
#    {'apparentTemperature': 68.05,
#     'cloudCover': 1,
#     'dewPoint': 64.54,
#     'humidity': 0.89,
#     'icon': 'rain',
#     'ozone': 333.2,
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.42,
#     'precipType': 'rain',
#     'pressure': 1009.09,
#     'summary': 'Drizzle',
#     'temperature': 68.05,
#     'time': 1496656800,
#     'visibility': 5.35,
#     'windBearing': 203,
#     'windSpeed': 6},
#    {'apparentTemperature': 68.53,
#     'cloudCover': 1,
#     'dewPoint': 65.39,
#     'humidity': 0.9,
#     'icon': 'rain',
#     'ozone': 331.8,
#     'precipIntensity': 0.0125,
#     'precipProbability': 0.54,
#     'precipType': 'rain',
#     'pressure': 1008.92,
#     'summary': 'Light Rain',
#     'temperature': 68.53,
#     'time': 1496660400,
#     'visibility': 4.84,
#     'windBearing': 203,
#     'windSpeed': 5.37},
#    {'apparentTemperature': 70.31,
#     'cloudCover': 0.99,
#     'dewPoint': 66.38,
#     'humidity': 0.87,
#     'icon': 'rain',
#     'ozone': 330.5,
#     'precipIntensity': 0.0233,
#     'precipProbability': 0.63,
#     'precipType': 'rain',
#     'pressure': 1008.77,
#     'summary': 'Light Rain',
#     'temperature': 70.31,
#     'time': 1496664000,
#     'visibility': 6.92,
#     'windBearing': 202,
#     'windSpeed': 5.05},
#    {'apparentTemperature': 71.41,
#     'cloudCover': 1,
#     'dewPoint': 67.04,
#     'humidity': 0.86,
#     'icon': 'rain',
#     'ozone': 329.34,
#     'precipIntensity': 0.0476,
#     'precipProbability': 0.72,
#     'precipType': 'rain',
#     'pressure': 1008.66,
#     'summary': 'Light Rain',
#     'temperature': 71.41,
#     'time': 1496667600,
#     'visibility': 4.1,
#     'windBearing': 200,
#     'windSpeed': 5.25},
#    {'apparentTemperature': 72.59,
#     'cloudCover': 1,
#     'dewPoint': 67.76,
#     'humidity': 0.85,
#     'icon': 'rain',
#     'ozone': 328.28,
#     'precipIntensity': 0.079,
#     'precipProbability': 0.77,
#     'precipType': 'rain',
#     'pressure': 1008.57,
#     'summary': 'Rain',
#     'temperature': 72.59,
#     'time': 1496671200,
#     'visibility': 4.47,
#     'windBearing': 198,
#     'windSpeed': 5.6},
#    {'apparentTemperature': 73.53,
#     'cloudCover': 1,
#     'dewPoint': 68.35,
#     'humidity': 0.84,
#     'icon': 'rain',
#     'ozone': 327.72,
#     'precipIntensity': 0.1045,
#     'precipProbability': 0.8,
#     'precipType': 'rain',
#     'pressure': 1008.42,
#     'summary': 'Rain',
#     'temperature': 73.53,
#     'time': 1496674800,
#     'visibility': 4.93,
#     'windBearing': 194,
#     'windSpeed': 5.38},
#    {'apparentTemperature': 74.34,
#     'cloudCover': 1,
#     'dewPoint': 68.66,
#     'humidity': 0.83,
#     'icon': 'rain',
#     'ozone': 327.76,
#     'precipIntensity': 0.1068,
#     'precipProbability': 0.8,
#     'precipType': 'rain',
#     'pressure': 1008.08,
#     'summary': 'Rain',
#     'temperature': 74.34,
#     'time': 1496678400,
#     'visibility': 5.26,
#     'windBearing': 186,
#     'windSpeed': 4.54},
#    {'apparentTemperature': 75.02,
#     'cloudCover': 1,
#     'dewPoint': 68.74,
#     'humidity': 0.81,
#     'icon': 'rain',
#     'ozone': 328.3,
#     'precipIntensity': 0.0971,
#     'precipProbability': 0.79,
#     'precipType': 'rain',
#     'pressure': 1007.63,
#     'summary': 'Rain',
#     'temperature': 75.02,
#     'time': 1496682000,
#     'visibility': 5.71,
#     'windBearing': 180,
#     'windSpeed': 3.55},
#    {'apparentTemperature': 75.19,
#     'cloudCover': 1,
#     'dewPoint': 68.69,
#     'humidity': 0.8,
#     'icon': 'rain',
#     'ozone': 329.43,
#     'precipIntensity': 0.0953,
#     'precipProbability': 0.79,
#     'precipType': 'rain',
#     'pressure': 1007.19,
#     'summary': 'Rain',
#     'temperature': 75.19,
#     'time': 1496685600,
#     'visibility': 5.9,
#     'windBearing': 184,
#     'windSpeed': 2.45},
#    {'apparentTemperature': 73.94,
#     'cloudCover': 1,
#     'dewPoint': 67.73,
#     'humidity': 0.81,
#     'icon': 'rain',
#     'ozone': 331.56,
#     'precipIntensity': 0.1181,
#     'precipProbability': 0.81,
#     'precipType': 'rain',
#     'pressure': 1006.79,
#     'summary': 'Rain',
#     'temperature': 73.94,
#     'time': 1496689200,
#     'visibility': 5.03,
#     'windBearing': 188,
#     'windSpeed': 0.46},
#    {'apparentTemperature': 72.04,
#     'cloudCover': 1,
#     'dewPoint': 66.09,
#     'humidity': 0.82,
#     'icon': 'rain',
#     'ozone': 334.29,
#     'precipIntensity': 0.1444,
#     'precipProbability': 0.83,
#     'precipType': 'rain',
#     'pressure': 1006.41,
#     'summary': 'Rain',
#     'temperature': 72.04,
#     'time': 1496692800,
#     'visibility': 6.01,
#     'windBearing': 335,
#     'windSpeed': 0.87},
#    {'apparentTemperature': 69.72,
#     'cloudCover': 0.99,
#     'dewPoint': 65.09,
#     'humidity': 0.85,
#     'icon': 'rain',
#     'ozone': 336.48,
#     'precipIntensity': 0.1471,
#     'precipProbability': 0.83,
#     'precipType': 'rain',
#     'pressure': 1006.07,
#     'summary': 'Rain',
#     'temperature': 69.72,
#     'time': 1496696400,
#     'visibility': 7.42,
#     'windBearing': 322,
#     'windSpeed': 0.8},
#    {'apparentTemperature': 69.34,
#     'cloudCover': 0.91,
#     'dewPoint': 65.38,
#     'humidity': 0.87,
#     'icon': 'rain',
#     'ozone': 337.7,
#     'precipIntensity': 0.1126,
#     'precipProbability': 0.81,
#     'precipType': 'rain',
#     'pressure': 1005.79,
#     'summary': 'Rain',
#     'temperature': 69.34,
#     'time': 1496700000,
#     'visibility': 8.33,
#     'windBearing': 307,
#     'windSpeed': 0.16},
#    {'apparentTemperature': 69.34,
#     'cloudCover': 0.78,
#     'dewPoint': 65.98,
#     'humidity': 0.89,
#     'icon': 'rain',
#     'ozone': 338.39,
#     'precipIntensity': 0.0579,
#     'precipProbability': 0.74,
#     'precipType': 'rain',
#     'pressure': 1005.63,
#     'summary': 'Rain',
#     'temperature': 69.34,
#     'time': 1496703600,
#     'visibility': 9.03,
#     'windBearing': 146,
#     'windSpeed': 0.2},
#    {'apparentTemperature': 69.41,
#     'cloudCover': 0.66,
#     'dewPoint': 66.54,
#     'humidity': 0.91,
#     'icon': 'rain',
#     'ozone': 338.73,
#     'precipIntensity': 0.016,
#     'precipProbability': 0.57,
#     'precipType': 'rain',
#     'pressure': 1005.63,
#     'summary': 'Light Rain',
#     'temperature': 69.41,
#     'time': 1496707200,
#     'visibility': 9.48,
#     'windBearing': 207,
#     'windSpeed': 0.38},
#    {'apparentTemperature': 69.05,
#     'cloudCover': 0.56,
#     'dewPoint': 66.7,
#     'humidity': 0.92,
#     'icon': 'partly-cloudy-night',
#     'ozone': 338.54,
#     'precipIntensity': 0.0029,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'pressure': 1005.85,
#     'summary': 'Partly Cloudy',
#     'temperature': 69.05,
#     'time': 1496710800,
#     'visibility': 9.73,
#     'windBearing': 244,
#     'windSpeed': 1.34},
#    {'apparentTemperature': 67.97,
#     'cloudCover': 0.44,
#     'dewPoint': 66.22,
#     'humidity': 0.94,
#     'icon': 'partly-cloudy-night',
#     'ozone': 337.99,
#     'precipIntensity': 0.0032,
#     'precipProbability': 0.11,
#     'precipType': 'rain',
#     'pressure': 1006.09,
#     'summary': 'Partly Cloudy',
#     'temperature': 67.97,
#     'time': 1496714400,
#     'visibility': 10,
#     'windBearing': 249,
#     'windSpeed': 2.48},
#    {'apparentTemperature': 66.65,
#     'cloudCover': 0.38,
#     'dewPoint': 65.18,
#     'humidity': 0.95,
#     'icon': 'partly-cloudy-night',
#     'ozone': 337.77,
#     'precipIntensity': 0.0047,
#     'precipProbability': 0.19,
#     'precipType': 'rain',
#     'pressure': 1006.17,
#     'summary': 'Partly Cloudy',
#     'temperature': 66.65,
#     'time': 1496718000,
#     'visibility': 10,
#     'windBearing': 252,
#     'windSpeed': 3.06},
#    {'apparentTemperature': 66.13,
#     'cloudCover': 0.4,
#     'dewPoint': 64.57,
#     'humidity': 0.95,
#     'icon': 'partly-cloudy-night',
#     'ozone': 338.17,
#     'precipIntensity': 0.0038,
#     'precipProbability': 0.14,
#     'precipType': 'rain',
#     'pressure': 1006.06,
#     'summary': 'Partly Cloudy',
#     'temperature': 66.13,
#     'time': 1496721600,
#     'visibility': 10,
#     'windBearing': 257,
#     'windSpeed': 3.37},
#    {'apparentTemperature': 65.56,
#     'cloudCover': 0.45,
#     'dewPoint': 63.72,
#     'humidity': 0.94,
#     'icon': 'partly-cloudy-night',
#     'ozone': 338.89,
#     'precipIntensity': 0.0041,
#     'precipProbability': 0.16,
#     'precipType': 'rain',
#     'pressure': 1005.85,
#     'summary': 'Partly Cloudy',
#     'temperature': 65.56,
#     'time': 1496725200,
#     'visibility': 10,
#     'windBearing': 262,
#     'windSpeed': 3.55},
#    {'apparentTemperature': 64.79,
#     'cloudCover': 0.49,
#     'dewPoint': 62.75,
#     'humidity': 0.93,
#     'icon': 'partly-cloudy-night',
#     'ozone': 339.76,
#     'precipIntensity': 0.0043,
#     'precipProbability': 0.17,
#     'precipType': 'rain',
#     'pressure': 1005.67,
#     'summary': 'Partly Cloudy',
#     'temperature': 64.79,
#     'time': 1496728800,
#     'visibility': 10,
#     'windBearing': 267,
#     'windSpeed': 3.66},
#    {'apparentTemperature': 63.87,
#     'cloudCover': 0.51,
#     'dewPoint': 61.81,
#     'humidity': 0.93,
#     'icon': 'partly-cloudy-night',
#     'ozone': 340.68,
#     'precipIntensity': 0.004,
#     'precipProbability': 0.15,
#     'precipType': 'rain',
#     'pressure': 1005.5,
#     'summary': 'Partly Cloudy',
#     'temperature': 63.87,
#     'time': 1496732400,
#     'visibility': 10,
#     'windBearing': 272,
#     'windSpeed': 3.77},
#    {'apparentTemperature': 63.08,
#     'cloudCover': 0.51,
#     'dewPoint': 61.06,
#     'humidity': 0.93,
#     'icon': 'partly-cloudy-night',
#     'ozone': 341.74,
#     'precipIntensity': 0.0035,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'pressure': 1005.36,
#     'summary': 'Partly Cloudy',
#     'temperature': 63.08,
#     'time': 1496736000,
#     'visibility': 10,
#     'windBearing': 278,
#     'windSpeed': 3.85},
#    {'apparentTemperature': 62.7,
#     'cloudCover': 0.5,
#     'dewPoint': 60.57,
#     'humidity': 0.93,
#     'icon': 'partly-cloudy-night',
#     'ozone': 343.07,
#     'precipIntensity': 0.003,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'pressure': 1005.36,
#     'summary': 'Partly Cloudy',
#     'temperature': 62.7,
#     'time': 1496739600,
#     'visibility': 10,
#     'windBearing': 284,
#     'windSpeed': 4.01},
#    {'apparentTemperature': 63.29,
#     'cloudCover': 0.44,
#     'dewPoint': 61.01,
#     'humidity': 0.92,
#     'icon': 'partly-cloudy-day',
#     'ozone': 344.94,
#     'precipIntensity': 0.0024,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'pressure': 1005.6,
#     'summary': 'Partly Cloudy',
#     'temperature': 63.29,
#     'time': 1496743200,
#     'visibility': 10,
#     'windBearing': 292,
#     'windSpeed': 4.32},
#    {'apparentTemperature': 64.57,
#     'cloudCover': 0.36,
#     'dewPoint': 61.98,
#     'humidity': 0.91,
#     'icon': 'partly-cloudy-day',
#     'ozone': 347.08,
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'pressure': 1005.94,
#     'summary': 'Partly Cloudy',
#     'temperature': 64.57,
#     'time': 1496746800,
#     'visibility': 10,
#     'windBearing': 300,
#     'windSpeed': 4.88},
#    {'apparentTemperature': 66.21,
#     'cloudCover': 0.3,
#     'dewPoint': 62.53,
#     'humidity': 0.88,
#     'icon': 'partly-cloudy-day',
#     'ozone': 348.84,
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'pressure': 1006.23,
#     'summary': 'Partly Cloudy',
#     'temperature': 66.21,
#     'time': 1496750400,
#     'visibility': 10,
#     'windBearing': 305,
#     'windSpeed': 5.63},
#    {'apparentTemperature': 68.75,
#     'cloudCover': 0.27,
#     'dewPoint': 62.39,
#     'humidity': 0.8,
#     'icon': 'partly-cloudy-day',
#     'ozone': 349.96,
#     'precipIntensity': 0.0014,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.45,
#     'summary': 'Partly Cloudy',
#     'temperature': 68.75,
#     'time': 1496754000,
#     'visibility': 10,
#     'windBearing': 305,
#     'windSpeed': 6.43},
#    {'apparentTemperature': 71.8,
#     'cloudCover': 0.24,
#     'dewPoint': 61.45,
#     'humidity': 0.7,
#     'icon': 'clear-day',
#     'ozone': 350.69,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.62,
#     'summary': 'Clear',
#     'temperature': 71.8,
#     'time': 1496757600,
#     'visibility': 10,
#     'windBearing': 304,
#     'windSpeed': 6.97},
#    {'apparentTemperature': 74.55,
#     'cloudCover': 0.22,
#     'dewPoint': 60.2,
#     'humidity': 0.61,
#     'icon': 'clear-day',
#     'ozone': 351.17,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.67,
#     'summary': 'Clear',
#     'temperature': 74.55,
#     'time': 1496761200,
#     'visibility': 10,
#     'windBearing': 303,
#     'windSpeed': 7.1},
#    {'apparentTemperature': 76.59,
#     'cloudCover': 0.17,
#     'dewPoint': 59.13,
#     'humidity': 0.55,
#     'icon': 'clear-day',
#     'ozone': 351.3,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.57,
#     'summary': 'Clear',
#     'temperature': 76.59,
#     'time': 1496764800,
#     'visibility': 10,
#     'windBearing': 301,
#     'windSpeed': 7.02},
#    {'apparentTemperature': 78.16,
#     'cloudCover': 0.12,
#     'dewPoint': 58.13,
#     'humidity': 0.5,
#     'icon': 'clear-day',
#     'ozone': 351.17,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.37,
#     'summary': 'Clear',
#     'temperature': 78.16,
#     'time': 1496768400,
#     'visibility': 10,
#     'windBearing': 300,
#     'windSpeed': 6.81},
#    {'apparentTemperature': 79.25,
#     'cloudCover': 0.11,
#     'dewPoint': 57.25,
#     'humidity': 0.47,
#     'icon': 'clear-day',
#     'ozone': 351.21,
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1006.13,
#     'summary': 'Clear',
#     'temperature': 79.25,
#     'time': 1496772000,
#     'visibility': 10,
#     'windBearing': 298,
#     'windSpeed': 6.52},
#    {'apparentTemperature': 79.88,
#     'cloudCover': 0.17,
#     'dewPoint': 56.48,
#     'humidity': 0.45,
#     'icon': 'clear-day',
#     'ozone': 351.71,
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'pressure': 1005.8,
#     'summary': 'Clear',
#     'temperature': 79.88,
#     'time': 1496775600,
#     'visibility': 10,
#     'windBearing': 296,
#     'windSpeed': 6.28},
#    {'apparentTemperature': 80.26,
#     'cloudCover': 0.26,
#     'dewPoint': 56.03,
#     'humidity': 0.44,
#     'icon': 'partly-cloudy-day',
#     'ozone': 352.38,
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1005.44,
#     'summary': 'Partly Cloudy',
#     'temperature': 80.01,
#     'time': 1496779200,
#     'visibility': 10,
#     'windBearing': 293,
#     'windSpeed': 6.04},
#    {'apparentTemperature': 79.06,
#     'cloudCover': 0.34,
#     'dewPoint': 55.88,
#     'humidity': 0.45,
#     'icon': 'partly-cloudy-day',
#     'ozone': 352.72,
#     'precipIntensity': 0.0009,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'pressure': 1005.3,
#     'summary': 'Partly Cloudy',
#     'temperature': 79.06,
#     'time': 1496782800,
#     'visibility': 10,
#     'windBearing': 293,
#     'windSpeed': 5.66}],
#   'icon': 'rain',
#   'summary': 'Rain starting tomorrow morning.'},
#  'latitude': 38.0293,
#  'longitude': -78.4767,
#  'minutely': {'data': [{'precipIntensity': 0,
#     'precipProbability': 0,
#     'time': 1496611740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496611800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496611860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496611920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496611980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496612940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613900},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496613960},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614020},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614080},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614140},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614200},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614260},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614320},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614380},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614440},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614500},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614560},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614620},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614680},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496614980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496615340}],
#   'icon': 'clear-day',
#   'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'offset', 'currently', 'minutely', 'hourly', 'daily', 'flags'])

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data['currently']
# Out:
# {'apparentTemperature': 85.8,
#  'cloudCover': 0.23,
#  'dewPoint': 61.22,
#  'humidity': 0.44,
#  'icon': 'clear-day',
#  'nearestStormBearing': 145,
#  'nearestStormDistance': 62,
#  'ozone': 344.1,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'pressure': 1010.45,
#  'summary': 'Clear',
#  'temperature': 85.55,
#  'time': 1496611765,
#  'visibility': 10,
#  'windBearing': 177,
#  'windSpeed': 7.52}

# %%
print("The current wind speed is", data['currently']['windSpeed'], "miles per hour")
# Out:
# The current wind speed is 7.52 miles per hour

# %%
data['currently']['apparentTemperature'] - data['currently']['temperature']
# Out:
# 0.25

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'offset', 'currently', 'minutely', 'hourly', 'daily', 'flags'])

# %%
type(data['daily'])
# Out:
# dict

# %%
data['daily'].keys()
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
type(data['daily']['data'])
# Out:
# list

# %%
data['daily']['data']
# Out:
# [{'apparentTemperatureMax': 86.32,
#   'apparentTemperatureMaxTime': 1496613600,
#   'apparentTemperatureMin': 55.5,
#   'apparentTemperatureMinTime': 1496566800,
#   'cloudCover': 0.15,
#   'dewPoint': 58.01,
#   'humidity': 0.62,
#   'icon': 'partly-cloudy-night',
#   'moonPhase': 0.35,
#   'ozone': 345.66,
#   'precipIntensity': 0.0005,
#   'precipIntensityMax': 0.0049,
#   'precipIntensityMaxTime': 1496631600,
#   'precipProbability': 0.2,
#   'precipType': 'rain',
#   'pressure': 1013.85,
#   'summary': 'Mostly cloudy starting in the evening.',
#   'sunriseTime': 1496570001,
#   'sunsetTime': 1496622847,
#   'temperatureMax': 86.25,
#   'temperatureMaxTime': 1496606400,
#   'temperatureMin': 55.5,
#   'temperatureMinTime': 1496566800,
#   'time': 1496548800,
#   'visibility': 9.97,
#   'windBearing': 190,
#   'windSpeed': 3.57},
#  {'apparentTemperatureMax': 75.19,
#   'apparentTemperatureMaxTime': 1496685600,
#   'apparentTemperatureMin': 66.65,
#   'apparentTemperatureMinTime': 1496718000,
#   'cloudCover': 0.88,
#   'dewPoint': 66.15,
#   'humidity': 0.86,
#   'icon': 'rain',
#   'moonPhase': 0.38,
#   'ozone': 333.78,
#   'precipIntensity': 0.0498,
#   'precipIntensityMax': 0.1471,
#   'precipIntensityMaxTime': 1496696400,
#   'precipProbability': 0.83,
#   'precipType': 'rain',
#   'pressure': 1007.9,
#   'summary': 'Rain until evening.',
#   'sunriseTime': 1496656385,
#   'sunsetTime': 1496709283,
#   'temperatureMax': 75.19,
#   'temperatureMaxTime': 1496685600,
#   'temperatureMin': 66.65,
#   'temperatureMinTime': 1496718000,
#   'time': 1496635200,
#   'visibility': 7.36,
#   'windBearing': 200,
#   'windSpeed': 3.57},
#  {'apparentTemperatureMax': 80.26,
#   'apparentTemperatureMaxTime': 1496779200,
#   'apparentTemperatureMin': 61.68,
#   'apparentTemperatureMinTime': 1496804400,
#   'cloudCover': 0.31,
#   'dewPoint': 59.15,
#   'humidity': 0.71,
#   'icon': 'partly-cloudy-day',
#   'moonPhase': 0.41,
#   'ozone': 348.02,
#   'precipIntensity': 0.0019,
#   'precipIntensityMax': 0.0043,
#   'precipIntensityMaxTime': 1496728800,
#   'precipProbability': 0.17,
#   'precipType': 'rain',
#   'pressure': 1006.14,
#   'summary': 'Partly cloudy in the morning.',
#   'sunriseTime': 1496742771,
#   'sunsetTime': 1496795718,
#   'temperatureMax': 80.01,
#   'temperatureMaxTime': 1496779200,
#   'temperatureMin': 61.68,
#   'temperatureMinTime': 1496804400,
#   'time': 1496721600,
#   'visibility': 10,
#   'windBearing': 296,
#   'windSpeed': 4.95},
#  {'apparentTemperatureMax': 73.3,
#   'apparentTemperatureMaxTime': 1496862000,
#   'apparentTemperatureMin': 55.82,
#   'apparentTemperatureMinTime': 1496826000,
#   'cloudCover': 0.55,
#   'dewPoint': 56.89,
#   'humidity': 0.78,
#   'icon': 'rain',
#   'moonPhase': 0.44,
#   'ozone': 359.73,
#   'precipIntensity': 0.0078,
#   'precipIntensityMax': 0.025,
#   'precipIntensityMaxTime': 1496883600,
#   'precipProbability': 0.64,
#   'precipType': 'rain',
#   'pressure': 1009.64,
#   'summary': 'Light rain starting in the afternoon.',
#   'sunriseTime': 1496829158,
#   'sunsetTime': 1496882152,
#   'temperatureMax': 73.3,
#   'temperatureMaxTime': 1496862000,
#   'temperatureMin': 55.82,
#   'temperatureMinTime': 1496826000,
#   'time': 1496808000,
#   'visibility': 10,
#   'windBearing': 9,
#   'windSpeed': 4.24},
#  {'apparentTemperatureMax': 67.86,
#   'apparentTemperatureMaxTime': 1496948400,
#   'apparentTemperatureMin': 54.67,
#   'apparentTemperatureMinTime': 1496930400,
#   'cloudCover': 0.75,
#   'dewPoint': 56.64,
#   'humidity': 0.88,
#   'icon': 'rain',
#   'moonPhase': 0.47,
#   'ozone': 374.25,
#   'precipIntensity': 0.0066,
#   'precipIntensityMax': 0.0158,
#   'precipIntensityMaxTime': 1496894400,
#   'precipProbability': 0.57,
#   'precipType': 'rain',
#   'pressure': 1011.06,
#   'summary': 'Light rain starting in the afternoon, continuing until evening.',
#   'sunriseTime': 1496915548,
#   'sunsetTime': 1496968584,
#   'temperatureMax': 67.86,
#   'temperatureMaxTime': 1496948400,
#   'temperatureMin': 54.67,
#   'temperatureMinTime': 1496930400,
#   'time': 1496894400,
#   'windBearing': 35,
#   'windSpeed': 3.33},
#  {'apparentTemperatureMax': 79.33,
#   'apparentTemperatureMaxTime': 1497042000,
#   'apparentTemperatureMin': 53.73,
#   'apparentTemperatureMinTime': 1496995200,
#   'cloudCover': 0.16,
#   'dewPoint': 56.69,
#   'humidity': 0.74,
#   'icon': 'partly-cloudy-day',
#   'moonPhase': 0.51,
#   'ozone': 352.4,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1012.08,
#   'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#   'sunriseTime': 1497001939,
#   'sunsetTime': 1497055015,
#   'temperatureMax': 79.33,
#   'temperatureMaxTime': 1497042000,
#   'temperatureMin': 53.73,
#   'temperatureMinTime': 1496995200,
#   'time': 1496980800,
#   'windBearing': 227,
#   'windSpeed': 2.2},
#  {'apparentTemperatureMax': 83.01,
#   'apparentTemperatureMaxTime': 1497128400,
#   'apparentTemperatureMin': 62.11,
#   'apparentTemperatureMinTime': 1497085200,
#   'cloudCover': 0.09,
#   'dewPoint': 60.36,
#   'humidity': 0.7,
#   'icon': 'partly-cloudy-day',
#   'moonPhase': 0.54,
#   'ozone': 355.2,
#   'precipIntensity': 0.0009,
#   'precipIntensityMax': 0.0019,
#   'precipIntensityMaxTime': 1497146400,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'pressure': 1013.71,
#   'summary': 'Partly cloudy in the evening.',
#   'sunriseTime': 1497088332,
#   'sunsetTime': 1497141445,
#   'temperatureMax': 83.21,
#   'temperatureMaxTime': 1497128400,
#   'temperatureMin': 62.11,
#   'temperatureMinTime': 1497085200,
#   'time': 1497067200,
#   'windBearing': 252,
#   'windSpeed': 3.54},
#  {'apparentTemperatureMax': 85.8,
#   'apparentTemperatureMaxTime': 1497211200,
#   'apparentTemperatureMin': 63.44,
#   'apparentTemperatureMinTime': 1497171600,
#   'cloudCover': 0,
#   'dewPoint': 61.45,
#   'humidity': 0.66,
#   'icon': 'clear-day',
#   'moonPhase': 0.56,
#   'ozone': 342.17,
#   'precipIntensity': 0.0011,
#   'precipIntensityMax': 0.0018,
#   'precipIntensityMaxTime': 1497153600,
#   'precipProbability': 0.04,
#   'precipType': 'rain',
#   'pressure': 1016.82,
#   'summary': 'Clear throughout the day.',
#   'sunriseTime': 1497174726,
#   'sunsetTime': 1497227874,
#   'temperatureMax': 86.89,
#   'temperatureMaxTime': 1497211200,
#   'temperatureMin': 63.44,
#   'temperatureMinTime': 1497171600,
#   'time': 1497153600,
#   'windBearing': 246,
#   'windSpeed': 0.87}]

# %%
today = data['daily']['data'][0]
today
# Out:
# {'apparentTemperatureMax': 86.32,
#  'apparentTemperatureMaxTime': 1496613600,
#  'apparentTemperatureMin': 55.5,
#  'apparentTemperatureMinTime': 1496566800,
#  'cloudCover': 0.15,
#  'dewPoint': 58.01,
#  'humidity': 0.62,
#  'icon': 'partly-cloudy-night',
#  'moonPhase': 0.35,
#  'ozone': 345.66,
#  'precipIntensity': 0.0005,
#  'precipIntensityMax': 0.0049,
#  'precipIntensityMaxTime': 1496631600,
#  'precipProbability': 0.2,
#  'precipType': 'rain',
#  'pressure': 1013.85,
#  'summary': 'Mostly cloudy starting in the evening.',
#  'sunriseTime': 1496570001,
#  'sunsetTime': 1496622847,
#  'temperatureMax': 86.25,
#  'temperatureMaxTime': 1496606400,
#  'temperatureMin': 55.5,
#  'temperatureMinTime': 1496566800,
#  'time': 1496548800,
#  'visibility': 9.97,
#  'windBearing': 190,
#  'windSpeed': 3.57}

# %%
print("Our moon phase is", today['moonPhase'])
# Out:
# Our moon phase is 0.35

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
today.keys()
# Out:
# dict_keys(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase', 'precipIntensity', 'precipIntensityMax', 'precipIntensityMaxTime', 'precipProbability', 'precipType', 'temperatureMin', 'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin', 'apparentTemperatureMinTime', 'apparentTemperatureMax', 'apparentTemperatureMaxTime', 'dewPoint', 'humidity', 'windSpeed', 'windBearing', 'visibility', 'cloudCover', 'pressure', 'ozone'])

# %%
today['temperatureMin']
# Out:
# 55.5

# %%
today['temperatureMax']
# Out:
# 86.25

# %%
today['temperatureMax'] - today['temperatureMin']
# Out:
# 30.75

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
type(data['daily'])
# Out:
# dict

# %%
data['daily'].keys()
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
data['daily']['summary']
# Out:
# 'Light rain tomorrow through Thursday, with temperatures bottoming out at 68°F on Thursday.'

# %%
daily_forecasts = data['daily']['data']

# %%
len(daily_forecasts)
# Out:
# 8

# %%
type(daily_forecasts)
# Out:
# list

# %%
for day in daily_forecasts:
    # print(type(day))
    # print(day.keys())
    temp = day['temperatureMax']
    print("The high temperature is going to be", temp)
    if temp > 85:
        print("It is going to be hot out!")
    elif temp > 65:
        print("It is going to be warm out.")
    else:
        print("It is going to be cold out.")
# Out:
# The high temperature is going to be 86.25
# It is going to be hot out!
# The high temperature is going to be 75.19
# It is going to be warm out.
# The high temperature is going to be 80.01
# It is going to be warm out.
# The high temperature is going to be 73.3
# It is going to be warm out.
# The high temperature is going to be 67.86
# It is going to be warm out.
# The high temperature is going to be 79.33
# It is going to be warm out.
# The high temperature is going to be 83.21
# It is going to be warm out.
# The high temperature is going to be 86.89
# It is going to be hot out!

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
daily_forecasts[0].keys()
# Out:
# dict_keys(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase', 'precipIntensity', 'precipIntensityMax', 'precipIntensityMaxTime', 'precipProbability', 'precipType', 'temperatureMin', 'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin', 'apparentTemperatureMinTime', 'apparentTemperatureMax', 'apparentTemperatureMaxTime', 'dewPoint', 'humidity', 'windSpeed', 'windBearing', 'visibility', 'cloudCover', 'pressure', 'ozone'])

# %%
# What is the highest temp? Let's pick the first day.
high_temp = daily_forecasts[0]['temperatureMax']
hottest_day = daily_forecasts[0]['time']

for day in daily_forecasts:
    print("Today's temp is", day['temperatureMax'])
    if day['temperatureMax'] > high_temp:
        print("FOUND A NEW HIGH TEMPERATURE on", day['time'])
        high_temp = day['temperatureMax']
        hottest_day = day['time']

print("The highest tempeature is", high_temp, "on", hottest_day)
# Out:
# Today's temp is 86.25
# Today's temp is 75.19
# Today's temp is 80.01
# Today's temp is 73.3
# Today's temp is 67.86
# Today's temp is 79.33
# Today's temp is 83.21
# Today's temp is 86.89
# FOUND A NEW HIGH TEMPERATURE on 1497153600
# The highest tempeature is 86.89 on 1497153600

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
